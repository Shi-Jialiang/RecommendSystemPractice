# %% [markdown]
# # 用户冷启动-利用用户注册信息

# %%
# 导入包
import random
import math
import numpy as np
import time
from tqdm import tqdm, trange

# %% [markdown]
# ## 一. 通用函数定义

# %%
# 定义装饰器，监控运行时间
def timmer(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        res = func(*args, **kwargs)
        stop_time = time.time()
        print('Func %s, run time: %s' % (func.__name__, stop_time - start_time))
        return res
    return wrapper

# %% [markdown]
# ### 1. 数据处理相关
# 1. load data
# 2. split data

# %%
class Dataset():
    
    def __init__(self, fp, up):
        # fp: data file path
        # up: user profile path
        self.data, self.profile = self.loadData(fp, up)
    
    @timmer
    def loadData(self, fp, up):
        data = []
        for l in open(fp):
            # 去空格 取前面两项：用户名 和 音乐人Id
            data.append(tuple(l.strip().split('\t')[:2]))
        profile = {}
        # 存入用户ID 性别 年龄 国家
        for l in open(up):
            user, gender, age, country, _ = l.strip().split('\t')
            if age == '': 
                age = -1
            profile[user] = {'gender': gender, 'age': int(age), 'country': country}
        # 按照用户进行采样
        # 随机找5000个用户信息
        users = list(profile.keys())
        random.shuffle(users)
        users = set(users[:5000])
        
        # 如果存在于历史记录的用户在这5000个用户中 保留这些历史记录
        data = [x for x in data if x[0] in users]
        # 保留这5000个用户的信息
        profile = {k: profile[k] for k in users}
        return data, profile
    
    @timmer
    def splitData(self, M, k, seed=1):
        '''
        :params: data, 加载的所有(user, item)数据条目
        :params: M, 划分的数目，最后需要取M折的平均
        :params: k, 本次是第几次划分，k~[0, M)
        :params: seed, random的种子数，对于不同的k应设置成一样的
        :return: train, test
        '''
        train, test = [], []
        random.seed(seed)
        for user, item in self.data:
            # 这里与书中的不一致，本人认为取M-1较为合理，因randint是左右都覆盖的
            if random.randint(0, M-1) == k:  
                test.append((user, item))
            else:
                train.append((user, item))

        # 处理成字典的形式，user->set(items)
        def convert_dict(data):
            data_dict = {}
            for user, item in data:
                if user not in data_dict:
                    data_dict[user] = set()
                data_dict[user].add(item)
            data_dict = {k: list(data_dict[k]) for k in data_dict}
            return data_dict

        return convert_dict(train), convert_dict(test), self.profile

# %% [markdown]
# ### 2. 评价指标
# 1. Precision
# 2. Recall
# 3. Coverage

# %%
class Metric():
    
    def __init__(self, train, test, GetRecommendation):
        '''
        :params: train, 训练数据
        :params: test, 测试数据
        :params: GetRecommendation, 为某个用户获取推荐物品的接口函数
        '''
        self.train = train
        self.test = test
        self.GetRecommendation = GetRecommendation
        self.recs = self.getRec()
        
    # 为test中的每个用户进行推荐
    def getRec(self):
        recs = {}
        for user in self.test:
            rank = self.GetRecommendation(user)
            recs[user] = rank
        return recs
        
    # 定义精确率指标计算方式
    def precision(self):
        all, hit = 0, 0
        for user in self.test:
            test_items = set(self.test[user])
            rank = self.recs[user]
            for item, score in rank:
                if item in test_items:
                    hit += 1
            all += len(rank)
        return round(hit / all * 100, 2)
    
    # 定义召回率指标计算方式
    def recall(self):
        all, hit = 0, 0
        for user in self.test:
            test_items = set(self.test[user])
            rank = self.recs[user]
            for item, score in rank:
                if item in test_items:
                    hit += 1
            all += len(test_items)
        return round(hit / all * 100, 2)
    
    # 定义覆盖率指标计算方式
    def coverage(self):
        all_item, recom_item = set(), set()
        for user in self.test:
            if user in self.train:
                for item in self.train[user]:
                    all_item.add(item)
            rank = self.recs[user]
            for item, score in rank:
                recom_item.add(item)
        return round(len(recom_item) / len(all_item) * 100, 2)
    
    def eval(self):
        metric = {'Precision': self.precision(),
                  'Recall': self.recall(),
                  'Coverage': self.coverage()}
        print('Metric:', metric)
        return metric

# %% [markdown]
# ## 二. 算法实现
# 1. MostPopular
# 2. GenderMostPopular
# 3. AgeMostPopular
# 4. CountryMostPopular
# 5. DemographicMostPopular

# %%
# 1. MostPopular算法
def MostPopular(train, profile, N):
    '''
    :params: train, 训练数据
    :params: profile, 用户的注册信息
    :params: N, 推荐TopN物品的个数
    :return: GetRecommendation, 获取推荐结果的接口
    '''
    
    items = {}
    for user in train:
        for item in train[user]:
            if item not in items:
                items[item] = 0
            items[item] += 1
    items = list(sorted(items.items(), key=lambda x: x[1], reverse=True))
        
    # 获取接口函数
    def GetRecommendation(user):
        seen_items = set(train[user]) if user in train else set()
        recs = [x for x in items if x[0] not in seen_items][:N]
        return recs
    
    return GetRecommendation

# %%
# 2. GenderMostPopular算法
def GenderMostPopular(train, profile, N):
    '''
    :params: train, 训练数据
    :params: profile, 用户的注册信息
    :params: N, 推荐TopN物品的个数
    :return: GetRecommendation, 获取推荐结果的接口
    '''
    
    mitems, fitems = {}, {} # 男、女
    # 男 女分别看过的items
    for user in train:
        if profile[user]['gender'] == 'm':
            tmp = mitems
        elif profile[user]['gender'] == 'f':
            tmp = fitems
        for item in train[user]:
            if item not in tmp:
                tmp[item] = 0
            tmp[item] += 1
    mitems = list(sorted(mitems.items(), key=lambda x: x[1], reverse=True))
    fitems = list(sorted(fitems.items(), key=lambda x: x[1], reverse=True))
    
    mostPopular = MostPopular(train, profile, N)
    
    # 获取接口函数
    def GetRecommendation(user):
        seen_items = set(train[user]) if user in train else set()
        if profile[user]['gender'] == 'm':
            recs = [x for x in mitems if x[0] not in seen_items][:N]
        elif profile[user]['gender'] == 'f':
            recs = [x for x in fitems if x[0] not in seen_items][:N]
        else: # 没有提供性别信息的，按照MostPopular推荐
            recs = mostPopular(user)
        return recs
    
    return GetRecommendation

# %%
profile
# Out:
# {'fac3cde1a81ee1a0909d7cc35f34020b5ec560c4': {'gender': 'm',
#   'age': 34,
#   'country': 'United Kingdom'},
#  'd9ae3ee339d8996316733c26bf19c2eef943d69a': {'gender': 'm',
#   'age': 27,
#   'country': 'Finland'},
#  'efb3fc873bf2b0b5f94649f7a7c3402884322565': {'gender': 'f',
#   'age': 21,
#   'country': 'Poland'},
#  'bcc5c9ff591e3c7a69bf47fe7ea62576bd2d6ac6': {'gender': 'm',
#   'age': -1,
#   'country': 'Guadeloupe'},
#  '6d18a9ca7339aa6f34349b1bcaf44d9516c1bf79': {'gender': 'm',
#   'age': 30,
#   'country': 'United States'},
#  '159f0690167bd26082aadebbd65fb967d6c6ec20': {'gender': 'm',
#   'age': 38,
#   'country': 'United States'},
#  'd4e66c3edf4c23c37b17d8726d7ea8be1b119112': {'gender': 'm',
#   'age': 18,
#   'country': 'United States'},
#  'c8818b79e8ddafd7cfb1f48f1d9937e9e50c1e26': {'gender': 'f',
#   'age': 23,
#   'country': 'Lithuania'},
#  'd0bc1d9f892ba960d41bb9bd22f1a0e007a46783': {'gender': 'm',
#   'age': 33,
#   'country': 'United Kingdom'},
#  '5fe37e7d03b066a113da7a2c8b316c4099bfe4e2': {'gender': 'm',
#   'age': 17,
#   'country': 'Sweden'},
#  'f98436ee2cb9061073bf448f48248766175382fe': {'gender': 'm',
#   'age': 32,
#   'country': 'Czech Republic'},
#  '0d50fb4a9650534a212a886ad1aa5eed948c8c40': {'gender': 'm',
#   'age': 24,
#   'country': 'Singapore'},
#  'd651dcc5d30ce21a141cb21be5f72976c7921823': {'gender': 'm',
#   'age': 21,
#   'country': 'Poland'},
#  '2151292831cda8e8ea91831e5dc454956a398743': {'gender': 'm',
#   'age': -1,
#   'country': 'Dominican Republic'},
#  '89e7610307383067cc872111b6008dedc964af07': {'gender': 'm',
#   'age': 23,
#   'country': 'Poland'},
#  '85fff29e37ef17d41b5866225ca47bb46a80a70c': {'gender': 'f',
#   'age': 28,
#   'country': 'Italy'},
#  '22cd71959033c4dec21632badd4183abe27f622d': {'gender': 'm',
#   'age': 24,
#   'country': 'Korea, Republic of'},
#  '91a46a17da4076df235f60c304440cd2d38f4649': {'gender': '',
#   'age': -1,
#   'country': 'Canada'},
#  '899f0ce3b6beda4643d694eb1b65dccd412ccd69': {'gender': 'm',
#   'age': 33,
#   'country': 'Japan'},
#  'd1d6a5626d2596888aff58eced8ff2b748f7966c': {'gender': 'm',
#   'age': 21,
#   'country': 'Russian Federation'},
#  'b13ba22480521f42fa479527372867adb079f419': {'gender': 'm',
#   'age': 36,
#   'country': 'United States'},
#  '97a39bfd21d3672a68ce782b2d63908fbeed068d': {'gender': 'f',
#   'age': 24,
#   'country': 'United States'},
#  'be04631bbaf5cee64fd0266d35e41d638c852be4': {'gender': '',
#   'age': 31,
#   'country': 'Belgium'},
#  '2567a1e69adb03ce6bbddab68dfc01867274e1f4': {'gender': 'f',
#   'age': -1,
#   'country': 'United Kingdom'},
#  'f784cfaa5ce077688c5c12f960be9740597caccd': {'gender': 'f',
#   'age': -1,
#   'country': 'United States'},
#  '0cba57ce587629101f87cebfdfcec408bcda930b': {'gender': 'm',
#   'age': 26,
#   'country': 'Russian Federation'},
#  '71ae719f93bad7b41b3b8d4810405449e3581cdd': {'gender': 'm',
#   'age': 20,
#   'country': 'Belarus'},
#  '79bc5e4688abbc8e5ba169a5c6d1283cc120be8e': {'gender': 'f',
#   'age': 22,
#   'country': 'Sweden'},
#  'f39e204ec85e1dd7e00cfadefe00c93fa7df27d3': {'gender': 'f',
#   'age': 29,
#   'country': 'United Kingdom'},
#  '89f8e1ee09638bd0a955c6a928508c9d43c293ae': {'gender': 'm',
#   'age': -1,
#   'country': 'Germany'},
#  'afe6677a2572421a54dfe66116e853ae2f826820': {'gender': '',
#   'age': 54,
#   'country': 'Brazil'},
#  'd31e1f92c67aa3802f9d1bcbf76a0e3844fc6063': {'gender': 'm',
#   'age': 19,
#   'country': 'Lithuania'},
#  '2a77d04cfb0f8b0b97b028d82bb54c5dbf0d984e': {'gender': 'm',
#   'age': 33,
#   'country': 'United States'},
#  '9217a76fa356494b9c98e6ba1e950f17ced48c37': {'gender': 'f',
#   'age': 18,
#   'country': 'Poland'},
#  '8a9754e9f4d8d7a87677995495c56299f7d43c89': {'gender': 'm',
#   'age': 40,
#   'country': 'Finland'},
#  'a00bda4b02ea8539ba3f50a0ed4df111c8a7b273': {'gender': 'm',
#   'age': 21,
#   'country': 'Greece'},
#  '21c05f70d96388ce03cfcc36517ff7b2c29abc68': {'gender': 'f',
#   'age': 16,
#   'country': 'United States'},
#  '002d3f566c5ed4e36bf3332285a7b2ec0d433586': {'gender': 'f',
#   'age': 20,
#   'country': 'United States'},
#  '0b2e269655840d0956b806f8cef80a2334864bbd': {'gender': 'm',
#   'age': 22,
#   'country': 'Netherlands'},
#  'c964f214eb7bf4bc57abd5a090bed54b698088df': {'gender': '',
#   'age': -1,
#   'country': 'Turks and Caicos Islands'},
#  'c5bcb30306ad01a6c4355d21f33f2e23b5423d76': {'gender': 'm',
#   'age': 39,
#   'country': 'Germany'},
#  'fcdd6cd282e0be7e841dbff3b5f59af11fe89502': {'gender': 'm',
#   'age': 18,
#   'country': 'United Kingdom'},
#  '6583c81de447775cb9a33ec799f8b59267907716': {'gender': 'f',
#   'age': 37,
#   'country': 'France'},
#  '36090f72dc47f962edd9cd1975067b8467fbe927': {'gender': 'm',
#   'age': 21,
#   'country': 'United States'},
#  '7b581122b7757ebb8c165a73b6a7ac81b94c9c6f': {'gender': '',
#   'age': 37,
#   'country': 'Switzerland'},
#  '9a9f3139a5aad8652dd522b01f528fab5f1fdcbd': {'gender': 'm',
#   'age': 29,
#   'country': 'United States'},
#  '28901d93c82a79096c5f4064a7d946e93e9a63ca': {'gender': 'f',
#   'age': 34,
#   'country': 'United States'},
#  '4c294a8d8bc1e395c7d7747a80b964543efeaee4': {'gender': 'm',
#   'age': 29,
#   'country': 'United States'},
#  'f816d310911eedeb851ff8b44f86caeabc1a341f': {'gender': 'm',
#   'age': 18,
#   'country': 'United Kingdom'},
#  '0559d83cf045cb4edf2f1cba863435c5c22a2685': {'gender': 'm',
#   'age': 20,
#   'country': 'Germany'},
#  '6755c905624d8027bb72a2676321de92e7c21862': {'gender': 'm',
#   'age': 20,
#   'country': 'Belarus'},
#  'd7bf37094174f43fa895e3990c1d3cacc917fbb2': {'gender': 'm',
#   'age': -1,
#   'country': 'Germany'},
#  'bc17fb6df527b27b9e29e079422d581a07677dca': {'gender': 'f',
#   'age': 17,
#   'country': 'Germany'},
#  '6766e04a210634811aeeaf98a38dfe2e6c2aa382': {'gender': 'm',
#   'age': -1,
#   'country': 'United Kingdom'},
#  'bd4587d32f0247c17f469410e308d8e56f7d9c9c': {'gender': 'm',
#   'age': 21,
#   'country': 'United Kingdom'},
#  'f3c357042c56ef2afc0f10cf4cb48b0ab05df948': {'gender': 'm',
#   'age': 21,
#   'country': 'Russian Federation'},
#  'be30f5a8405273066d336e9f0366588323d6abc3': {'gender': 'm',
#   'age': -1,
#   'country': 'United Kingdom'},
#  'e92ebbeead4f6ad9ece5b639ce84b139b0e5dc84': {'gender': 'm',
#   'age': 24,
#   'country': 'United Kingdom'},
#  '1fc65a4cfe7aa29a13cc6c6643be7b1645b19af9': {'gender': 'f',
#   'age': -1,
#   'country': 'United States'},
#  '1792d963989b8eb3e9b191f62e8c0302d9d00d39': {'gender': '',
#   'age': 30,
#   'country': 'United States'},
#  '7bed659ddb76fe77a8ebf79e2ced4eb12c25b9d0': {'gender': '',
#   'age': 17,
#   'country': 'Brazil'},
#  'a48eda170f758edfcc0e050a98132ee4ceb3a163': {'gender': 'm',
#   'age': 24,
#   'country': 'Russian Federation'},
#  '6d0381387bb7b703a4100575c06f8908b342f2b9': {'gender': 'm',
#   'age': -1,
#   'country': 'Italy'},
#  '962c1db225aa17567a1730e4f70affa4fd752e2f': {'gender': 'm',
#   'age': 28,
#   'country': 'Congo, the Democratic Republic of the'},
#  'a6ad12a576f957947bd1ed7da9ef0654681df594': {'gender': '',
#   'age': 30,
#   'country': 'Brazil'},
#  '0f56c5d04f7278dd4072ed90b25494b2346a9803': {'gender': '',
#   'age': 19,
#   'country': 'United States'},
#  '124253a59a9ee0f2b40ac4df15a8c1acd323ea2b': {'gender': 'f',
#   'age': 43,
#   'country': 'Serbia'},
#  '93d871abc0c7cc4ccb98e3250bf11d3eed408e79': {'gender': 'm',
#   'age': 21,
#   'country': 'France'},
#  'bed2fb3366f1e87c223aa1e2c1f10decb75da67f': {'gender': 'm',
#   'age': 21,
#   'country': 'Russian Federation'},
#  '7e7da8e13be2d56da879ec4ba8d55b4e8bbf7061': {'gender': 'f',
#   'age': 29,
#   'country': 'United States'},
#  '4bab37163cb6df246a1b2632c97f3075fbb0cfe9': {'gender': 'm',
#   'age': 16,
#   'country': 'Australia'},
#  '9df356c6424556b931e4afe0302132b758100d52': {'gender': 'm',
#   'age': -1,
#   'country': 'United States'},
#  '42e673138cc72f2730db992a92cc6de8a5324e5c': {'gender': 'f',
#   'age': 26,
#   'country': 'United States'},
#  '984db94478a876930d55224a75920d6a204ac122': {'gender': 'm',
#   'age': 23,
#   'country': 'Bulgaria'},
#  '42c1f4cc671553b38baa22c9ca837984e6c37c65': {'gender': 'm',
#   'age': 24,
#   'country': 'Portugal'},
#  '036b70b51d55cee6a63c6fc94c1102f875af9100': {'gender': 'm',
#   'age': 19,
#   'country': 'United States'},
#  '38deae23256b28c66d754201224dccdba81f942c': {'gender': 'm',
#   'age': 23,
#   'country': 'Poland'},
#  'd8c17b8b19845185d12f0dac3171657e5292a8b4': {'gender': 'f',
#   'age': 22,
#   'country': 'Finland'},
#  '07bb7bad2c2f15b16749eb86dff7fa9799bed09f': {'gender': 'm',
#   'age': -1,
#   'country': 'Germany'},
#  '02d513ef077e239a45cff2502d46b596dcd837a9': {'gender': 'f',
#   'age': -1,
#   'country': 'Brazil'},
#  '6387da2024fa30d415a040644a75a6b344196021': {'gender': 'm',
#   'age': 17,
#   'country': 'United States'},
#  '069414f8822a995fe485187ed3c140ca512b4552': {'gender': 'm',
#   'age': -1,
#   'country': 'Poland'},
#  '67152c217869032b2e53aefa6548a10d042f354b': {'gender': 'm',
#   'age': 19,
#   'country': 'Poland'},
#  'a5ce127dbd4092f3d70904d5e87c986cce18723b': {'gender': 'm',
#   'age': 27,
#   'country': 'United States'},
#  '5ad7525b716fda638db5bfcfeb11866297a95b15': {'gender': 'm',
#   'age': 18,
#   'country': 'United Kingdom'},
#  '9659936380f1971cfe36e1dfccd3e1685a46ea2f': {'gender': 'm',
#   'age': 19,
#   'country': 'Sweden'},
#  '1979cf17ce2027cf317a4c17f7887168f58168a3': {'gender': 'f',
#   'age': 21,
#   'country': 'Italy'},
#  'da9e680cca7d6b024f134496528b23452fd69568': {'gender': 'm',
#   'age': 25,
#   'country': 'United States'},
#  '570dac533ce4972423adba7cec49f23c54ded49e': {'gender': 'f',
#   'age': 22,
#   'country': 'Russian Federation'},
#  '3fb6b938e6eee1e43ddbc21814ac8c11f470ab5a': {'gender': 'm',
#   'age': 18,
#   'country': 'Denmark'},
#  '8ae368f5b1a92e057b15a00dd87425adb02d9b1b': {'gender': '',
#   'age': 33,
#   'country': 'Spain'},
#  '464823d84153af4c8c0ed90fdbe6f47745bf9a7e': {'gender': 'm',
#   'age': 30,
#   'country': 'Thailand'},
#  'a033b2aa0fad6911978fe6b655ef3fa84dd56ebb': {'gender': 'm',
#   'age': 25,
#   'country': 'United Kingdom'},
#  'd9d1bb87a05627ed7fab65ac1e46d3c637298165': {'gender': 'm',
#   'age': 24,
#   'country': 'United Kingdom'},
#  '1a6f2e69aee7bb5046211bfb27c435bd00fe621b': {'gender': '',
#   'age': 19,
#   'country': 'Czech Republic'},
#  'b613cf35aa1765fa2231f72f202f20af0b58387e': {'gender': 'm',
#   'age': 29,
#   'country': 'Russian Federation'},
#  'e2373ea57b74b3ca0dc4ca3bd25ce33948a4cfc5': {'gender': 'm',
#   'age': 36,
#   'country': 'Netherlands'},
#  'fdc4a4f45ad99779f958288800adb13e4851ee67': {'gender': 'f',
#   'age': 29,
#   'country': 'Sweden'},
#  'fbd34ee400c9118150de2f33278d40a4d3932087': {'gender': 'm',
#   'age': 47,
#   'country': 'France'},
#  '15828657a8917f283adb6401626b4663ba66d300': {'gender': 'm',
#   'age': -1,
#   'country': 'United Kingdom'},
#  'eb70d39a29abbda191fa21bc969c5497d1f00993': {'gender': '',
#   'age': 20,
#   'country': 'Russian Federation'},
#  'fef4ec7e57cfa4c50728ac37cb3a376f4058d09e': {'gender': '',
#   'age': 24,
#   'country': 'United States'},
#  'd916d0f39a3eec249cb26e5482983fbafe91ee3f': {'gender': 'm',
#   'age': 25,
#   'country': 'Spain'},
#  '105fdc83620d9ad3c6c020f1600b66a07ab08891': {'gender': 'f',
#   'age': 24,
#   'country': 'Thailand'},
#  '0ae17519c75dce17e51f8c058df51cb4f4f6e155': {'gender': 'm',
#   'age': 28,
#   'country': 'Estonia'},
#  '7fc473cfaca09f93b9ee626c7dd06078dec7cef2': {'gender': 'm',
#   'age': 24,
#   'country': 'Israel'},
#  'd7183f43392344f9c7819616eceaea131fbf7cc4': {'gender': 'f',
#   'age': 18,
#   'country': 'Brazil'},
#  '36f7f917a3c0ba7d8b1e2a60e609daaf4c397161': {'gender': 'm',
#   'age': 19,
#   'country': 'Spain'},
#  '8c1a354d72aa9fcaaf740cd2ae713799b2ce4263': {'gender': 'm',
#   'age': 29,
#   'country': 'Germany'},
#  '63d9c3d22bd20e8b4035beb827966135dbe5d8a6': {'gender': 'm',
#   'age': 18,
#   'country': 'Serbia'},
#  'aa7491369f4b84000e47eea7de223ad66d8daaed': {'gender': 'f',
#   'age': 24,
#   'country': 'Turkey'},
#  '4a416f802733954c7a646b99307b544b01085499': {'gender': 'f',
#   'age': 26,
#   'country': 'Netherlands'},
#  '3f7a5e7735df73774be1284881d3062c1961360f': {'gender': 'm',
#   'age': 19,
#   'country': 'United Kingdom'},
#  'bd97ac0f6388499eb2bbfb1de93e44eeb5587250': {'gender': 'm',
#   'age': 19,
#   'country': 'Finland'},
#  'ac0457066a6e5ea4d2309de21fb3e3b1393a683b': {'gender': 'm',
#   'age': -1,
#   'country': 'United States'},
#  '38b0ecafd856e0bc6c7db409d2f0b22590715cb9': {'gender': 'm',
#   'age': 27,
#   'country': 'United States'},
#  'dc5ff7cb2ec64c3671cbde39eed5ac90371282d9': {'gender': 'm',
#   'age': 28,
#   'country': 'United States'},
#  'ec49e89e1a7e8b4c194084bf9d3078d5eb67be93': {'gender': 'm',
#   'age': 16,
#   'country': 'Bulgaria'},
#  'b4b435e178002f5dbcf66078a3a568f3c5bd9b4e': {'gender': 'f',
#   'age': 16,
#   'country': 'France'},
#  '7d28f19bcd920ca5773c4fae8d195540a3bc53db': {'gender': 'm',
#   'age': 50,
#   'country': 'Japan'},
#  '9e743bfbb047dade2afb29caed2fe360e3e19e40': {'gender': 'm',
#   'age': 31,
#   'country': 'Spain'},
#  'e59d3194aba4157de3027c25c90fecb06caaed1a': {'gender': 'f',
#   'age': -1,
#   'country': 'Brazil'},
#  'e64e0c43ea91f6af6d4c78c898b263bdc4392f81': {'gender': '',
#   'age': 28,
#   'country': 'Switzerland'},
#  '4d4760938948dab7c6b68a0b233c7e44c24e465a': {'gender': 'm',
#   'age': 20,
#   'country': 'Poland'},
#  '346a2b6e4b62a5dcc87f157f14b09a696de08cdd': {'gender': 'm',
#   'age': 23,
#   'country': 'Germany'},
#  '15482bc59efa2304d78c9a2e72c8cea19a9d872e': {'gender': 'm',
#   'age': -1,
#   'country': 'Brazil'},
#  '0f66e2e0a4fad968bf703dec628f52a0f9d83d15': {'gender': 'm',
#   'age': 24,
#   'country': 'Poland'},
#  'c6bb223155b3414162e73f902de8cb9250615770': {'gender': 'm',
#   'age': 28,
#   'country': 'Denmark'},
#  'ab2507795949f32dbf1104acf803bd15227870fd': {'gender': 'f',
#   'age': -1,
#   'country': 'United States'},
#  '13437a2b7fa4d91598aef50976b8bc2ab1da2c65': {'gender': 'f',
#   'age': 19,
#   'country': 'United Kingdom'},
#  'f43a27825801331a64fad85963039901a39ef126': {'gender': 'f',
#   'age': -1,
#   'country': 'Germany'},
#  '1baf2937661aeef27195b33227235a3807985500': {'gender': 'm',
#   'age': 26,
#   'country': 'Russian Federation'},
#  'b4c8315be0d9ed284981f1bd03ba2c6d4fa11640': {'gender': 'm',
#   'age': 28,
#   'country': 'Mexico'},
#  '5c3dac9da6436afde11ac19c6034fdba54fe43cd': {'gender': 'f',
#   'age': 21,
#   'country': 'Sweden'},
#  'b048e6feb80faa072b79f0377c074fd1a9e6aaef': {'gender': 'm',
#   'age': 24,
#   'country': 'Germany'},
#  'ba282b88b45e4cd9609ba841de39bcc242c5e921': {'gender': 'm',
#   'age': 33,
#   'country': 'Greece'},
#  '4fedba3ed44ea175586dd77d4450262d647a3e30': {'gender': 'm',
#   'age': 22,
#   'country': 'Spain'},
#  'aaee3f2170a135b517f76918cd3aeaedf0a148f4': {'gender': 'm',
#   'age': 18,
#   'country': 'Poland'},
#  '1f96c6c78b4db71af04b56ea051b22644407bba0': {'gender': 'f',
#   'age': 33,
#   'country': 'Sweden'},
#  '23e161d435182d626cb98189b763944ecebb48c6': {'gender': 'f',
#   'age': 22,
#   'country': 'Switzerland'},
#  '2d41d44ce554f88b3a5241e3b68aa8ce07265ba1': {'gender': 'm',
#   'age': 19,
#   'country': 'Germany'},
#  '4624849de3e1ba862b062bd27c2f4c9fdd054de4': {'gender': 'm',
#   'age': -1,
#   'country': 'United Kingdom'},
#  'e8416e2e6ae6acb01b44c726a570e675d5604e2d': {'gender': 'm',
#   'age': 17,
#   'country': 'Croatia'},
#  '542f1c4d6e9385919658ca21d09a5a82e070ee2d': {'gender': 'f',
#   'age': 27,
#   'country': 'Austria'},
#  'c93753a2af65d3d6655cc80fc381c768ac5bb7c1': {'gender': 'm',
#   'age': 24,
#   'country': 'Brazil'},
#  'd7c6d27c3c6bd2e6e36c518f2c8bd7b5a7c35161': {'gender': 'f',
#   'age': 22,
#   'country': 'Poland'},
#  '173fffa029d0e546288c13fb526a052a18b71e0c': {'gender': 'm',
#   'age': 22,
#   'country': 'United States'},
#  'deed36ae56843e9117f476f1a333f586a226ddb1': {'gender': 'm',
#   'age': 26,
#   'country': 'Portugal'},
#  '0e8ca9658d56a40e339fc8da2ba813e896031fd2': {'gender': 'f',
#   'age': 30,
#   'country': 'Germany'},
#  'd20493e2e8c40ec929f5a5b2da4acdd521e6fb8b': {'gender': 'f',
#   'age': 47,
#   'country': 'Venezuela'},
#  '9290c46f924b8d11bd240f22b4aa9faa5c975b4f': {'gender': 'm',
#   'age': 22,
#   'country': 'Finland'},
#  '68e6e595d6c3386140213545610a165df817b6c5': {'gender': 'm',
#   'age': -1,
#   'country': 'Germany'},
#  '32b6293a697b3c4e78fdfbf60f39e46e53adb375': {'gender': 'm',
#   'age': -1,
#   'country': 'Portugal'},
#  'b61d0c39a528a49fe1085e71f26bc99eca4614a6': {'gender': 'f',
#   'age': -1,
#   'country': 'Spain'},
#  'f65b4f0b1fa35fd43dfd9092bdba9135f103173b': {'gender': 'm',
#   'age': 23,
#   'country': 'Spain'},
#  'b1a30a5532894146e6412384d5fc0c59bc059993': {'gender': 'm',
#   'age': -1,
#   'country': 'Germany'},
#  'd454e453feea0a9ad89a5f8e51f4a6ff60419211': {'gender': 'm',
#   'age': 20,
#   'country': 'United Kingdom'},
#  '6f367e20620a5912681a0225d544e5d74b6bd15e': {'gender': 'f',
#   'age': 18,
#   'country': 'United States'},
#  'ba37d5326a673105cd8ce331b4bf5ee809ea9df8': {'gender': 'm',
#   'age': 20,
#   'country': 'Netherlands'},
#  'a00cc036fe299ea5c7f387906960d634a6a4deff': {'gender': '',
#   'age': 109,
#   'country': 'Japan'},
#  'edc042e1db5804b7d09bbcf95b92d5d205086071': {'gender': 'm',
#   'age': 20,
#   'country': 'Russian Federation'},
#  'bb2b735c4ea9c5d2575c12186b2fbc45a0ffcab9': {'gender': 'm',
#   'age': -1,
#   'country': 'Brazil'},
#  '14e4b7d2603e1e5464439c46a0854447bd5ed467': {'gender': '',
#   'age': -1,
#   'country': 'United Kingdom'},
#  '2b57cc08a229c69125a523572b434ae57b346666': {'gender': 'f',
#   'age': -1,
#   'country': 'Japan'},
#  '5f2f0f37d13da642e8012474cbf41d0bf0775b83': {'gender': 'm',
#   'age': 28,
#   'country': 'Germany'},
#  '37ffac9b46829b3fd9602750e06c575a00b5e0ae': {'gender': 'f',
#   'age': -1,
#   'country': 'United Kingdom'},
#  '96fa73cfd5475b103539e2f6afe150ea248087ec': {'gender': 'f',
#   'age': 18,
#   'country': 'United States'},
#  '2de46f1f9d44701623d41fb283c7486779ecb73b': {'gender': 'm',
#   'age': 22,
#   'country': 'Portugal'},
#  '728e12d5d92cc0484991e4e21a31bdaeafdc58e0': {'gender': 'm',
#   'age': -1,
#   'country': 'Germany'},
#  '293ec849cba25d8408648d5037dff3f60790d3d3': {'gender': 'm',
#   'age': 16,
#   'country': 'Chile'},
#  '0fc3c031fb929ff40fdcb1f3d3bc39806fcb7a0b': {'gender': 'f',
#   'age': 24,
#   'country': 'Norway'},
#  '800b95db926c27b00ef4e1fe862d676f74bc2301': {'gender': 'm',
#   'age': 22,
#   'country': 'Brazil'},
#  'e2000f0ebc9e55b97d2c591f29012bad191dacec': {'gender': '',
#   'age': 19,
#   'country': 'Sweden'},
#  '0c93f405c863446192e764ad39cffc9d3ed68869': {'gender': 'f',
#   'age': 19,
#   'country': 'Sweden'},
#  '3238c8ec91cbc06f0ecdb0cdbcb0d6a29b4ed287': {'gender': 'f',
#   'age': -1,
#   'country': 'Germany'},
#  'b3421b08b3e415078b3abf4f322355d13af41999': {'gender': 'm',
#   'age': 34,
#   'country': 'United Kingdom'},
#  '2d3887c7e027eec128827dba067c5cec4d3056fb': {'gender': 'f',
#   'age': 24,
#   'country': 'United Kingdom'},
#  'd7d21317011f6d3defa800aa64260b8956d161c5': {'gender': 'f',
#   'age': 19,
#   'country': 'Russian Federation'},
#  '9cd0b896fda3d6fe2246598a45c1ae52d4f775de': {'gender': 'f',
#   'age': -1,
#   'country': 'Germany'},
#  'ecf85e2454e014c762b38ae70c61ab9662699d1a': {'gender': '',
#   'age': 28,
#   'country': 'United Kingdom'},
#  '3abb3bbb9148542ce44619641d1c30fd77bd815b': {'gender': 'm',
#   'age': -1,
#   'country': 'Australia'},
#  'e2b53ce8617fd0d8915fc2022c5a0bfb02ab9618': {'gender': 'm',
#   'age': 25,
#   'country': 'Turkey'},
#  '7b5b1a092d158001cdfa71357ce1cfc326dc3f3a': {'gender': 'f',
#   'age': -1,
#   'country': 'United States'},
#  '9f257917199e13ebe031433e7574f02c94617624': {'gender': 'm',
#   'age': 20,
#   'country': 'United States'},
#  '14f21518fcbdc464dd94aaf1d3e04adf0e654cf3': {'gender': 'f',
#   'age': 27,
#   'country': 'Australia'},
#  'e5953614d4126f38605ccb5d8e9df20bbab9147e': {'gender': 'f',
#   'age': 16,
#   'country': 'United Kingdom'},
#  '6867d4ef90166d0e5bb5a7ad3224022598d6510c': {'gender': 'm',
#   'age': 21,
#   'country': 'Brazil'},
#  'ccf8beddbc6f42da7aff74745a700a3e7d093ab3': {'gender': '',
#   'age': -1,
#   'country': 'Australia'},
#  '8d530cdb8eca5a6e70f1a7089ac7a13803566e74': {'gender': 'm',
#   'age': 18,
#   'country': 'Poland'},
#  'cd3ece0cba5eb27480c7640bb752851dbcb0f72d': {'gender': 'f',
#   'age': 23,
#   'country': 'Brazil'},
#  '7d644d7fc4d5c480650af88cdc9c5eea72a0e2f7': {'gender': 'f',
#   'age': 17,
#   'country': 'Brazil'},
#  '83a37ea56edf1520f954c45ae3b423468df55306': {'gender': 'm',
#   'age': 21,
#   'country': 'Brazil'},
#  '36322243d5bf6fc9d131f6df5e1a002be17857c0': {'gender': 'm',
#   'age': 21,
#   'country': 'Chile'},
#  'd42021b024977173d4e357e605915addede57de9': {'gender': 'm',
#   'age': -1,
#   'country': 'Hungary'},
#  'b8a82e1291fff2dbeadab63eb960477839dd59a8': {'gender': 'f',
#   'age': 21,
#   'country': 'Netherlands'},
#  '2f7cd2168ae34ff93e81d84e88c51f6bdca497f6': {'gender': 'm',
#   'age': -1,
#   'country': 'United States'},
#  'c098b0c623481d771ef61f2db1672a1f1e0bb019': {'gender': 'm',
#   'age': 21,
#   'country': 'Argentina'},
#  '1f807f6b540fb90d7f68030132d236dfccf2f8ba': {'gender': 'm',
#   'age': 59,
#   'country': 'Australia'},
#  'e06a6f37ffbf6a6f1334d9723fd9f3604acbff51': {'gender': 'm',
#   'age': -1,
#   'country': 'Germany'},
#  '401889bbba3eab42022b4be20525b9412ae454b3': {'gender': 'm',
#   'age': 27,
#   'country': 'France'},
#  '4c30aafc791dd283a7b099055211204b87e3fb00': {'gender': 'm',
#   'age': 34,
#   'country': 'United States'},
#  '515629abc6bd3d46b8458be66db2866d0aa93501': {'gender': 'm',
#   'age': 39,
#   'country': 'Brazil'},
#  '7ee2c3d044ff2c876367ce12fcbc32df96f1134b': {'gender': 'm',
#   'age': 24,
#   'country': 'Czech Republic'},
#  'd5bc842e6c7dd16c3f719d2e1666d71081d11cf5': {'gender': 'm',
#   'age': 40,
#   'country': 'Switzerland'},
#  '13847d99b233b703d467984823703acf242b6cc5': {'gender': 'm',
#   'age': 29,
#   'country': 'France'},
#  '6f67125b481db97f8914ab7e3b4c4d698456d12a': {'gender': 'm',
#   'age': 21,
#   'country': 'United States'},
#  '403f51ceaafa95b5574c70a5cc0db62de99960fa': {'gender': 'm',
#   'age': 34,
#   'country': 'Netherlands'},
#  '8ee83d1001bdaf02cd1b0f85af7c3fca2addef32': {'gender': 'm',
#   'age': 28,
#   'country': 'United States'},
#  '6c94b66f5b292e1fbc3723ecb20ade80932f631d': {'gender': 'm',
#   'age': 1,
#   'country': 'United Kingdom'},
#  'e5a228d8a017da69bd2b2b2b520107020ce4d5d8': {'gender': 'f',
#   'age': 15,
#   'country': 'Poland'},
#  'ec0c553d385c0dc1ff28c4fb31fff5bf33dd4264': {'gender': 'm',
#   'age': 19,
#   'country': 'United States'},
#  '06343a290129e21ace2565a49e38e9b851b7b3e3': {'gender': 'm',
#   'age': 18,
#   'country': 'Czech Republic'},
#  '45ced2de81d3051529b8862beeea853766c59644': {'gender': 'm',
#   'age': -1,
#   'country': 'United Kingdom'},
#  '7884b93819f8e78fc6e679c599937170f4b45d23': {'gender': '',
#   'age': 36,
#   'country': 'Denmark'},
#  'abc5cb301663f1e34ac1e0554bf93db79f834084': {'gender': 'f',
#   'age': 23,
#   'country': 'Ukraine'},
#  '9affad379debfc047deaea5fe03d38455084ba1d': {'gender': 'm',
#   'age': 23,
#   'country': 'Malaysia'},
#  'defbac1deff8cbf94933bf87c18d2a702418bba8': {'gender': 'f',
#   'age': -1,
#   'country': 'Germany'},
#  '3dad49e0b6fe3898c0b0fb91cc4a3f7c449d682c': {'gender': 'f',
#   'age': 26,
#   'country': 'Turkey'},
#  '2827243f461e2c4afb1a46f0fbdab6bd7376bbcc': {'gender': 'm',
#   'age': -1,
#   'country': 'United States'},
#  '510779490b9664339c77a1b73757c34f0b76ee8c': {'gender': 'm',
#   'age': -1,
#   'country': 'United Kingdom'},
#  'dc6cec5629a0e17350ef1ec7db84ae815c0d3556': {'gender': 'f',
#   'age': 23,
#   'country': 'United States'},
#  '4bcb8df4b253419cb9ea84b0b55c49571e1771c7': {'gender': 'm',
#   'age': 38,
#   'country': 'Germany'},
#  '20b3a4fd77ae5fd7c40517a81eace8e7671046d5': {'gender': 'f',
#   'age': 28,
#   'country': 'Germany'},
#  '75d59b51d39382c77f6814f831e33f7f0c4c34ef': {'gender': 'm',
#   'age': 33,
#   'country': 'Netherlands'},
#  '44929d79b1982efcb3724f8cf33e0c7ee0ed0020': {'gender': 'm',
#   'age': 37,
#   'country': 'Mexico'},
#  'a0f1c461060373d5a05e0437560243833411bc59': {'gender': 'm',
#   'age': -1,
#   'country': 'Germany'},
#  '9155c68803824f7eb3d9f00239118ca64c023d41': {'gender': 'f',
#   'age': 39,
#   'country': 'United Kingdom'},
#  '3cf397f81fb9ac4769a330c0effc61af85d4333e': {'gender': 'm',
#   'age': 101,
#   'country': 'Netherlands'},
#  'd63c1c0ec98fccc2c35109dc39f53060334f6740': {'gender': 'f',
#   'age': 27,
#   'country': 'Netherlands'},
#  '920ecc66bdccab856f4a2df34596d6f387510000': {'gender': 'm',
#   'age': 21,
#   'country': 'Kazakhstan'},
#  'eec908765325486dba0385e1af00cbc33d7745ab': {'gender': 'f',
#   'age': 25,
#   'country': 'Germany'},
#  '9731e1fceb2feecc12da085284ce6ba2440b3ea5': {'gender': 'm',
#   'age': 17,
#   'country': 'Romania'},
#  '0c6b00d2f56b610553305b46fe53bf3f9729d216': {'gender': 'm',
#   'age': 19,
#   'country': 'Germany'},
#  'dfa9d409909a895241a480bd3ecd279a5deb5b77': {'gender': 'm',
#   'age': 25,
#   'country': 'Spain'},
#  'e8b11f069e8798d3478b7a5a34de32c882b753fb': {'gender': 'm',
#   'age': -1,
#   'country': 'Ukraine'},
#  '4cdd1c411df2dcdcf56bcda7b8c4de576875c31a': {'gender': 'm',
#   'age': 36,
#   'country': 'United States'},
#  '79b97dedc9c55f3f9f53cb3f9539548b9731bce6': {'gender': 'm',
#   'age': 36,
#   'country': 'Brazil'},
#  '6ece01263f8ac07e3515adf5b8fd64f6d94bda25': {'gender': 'm',
#   'age': 16,
#   'country': 'United States'},
#  '71369386880820f0cc75aa9d85ef003429064d90': {'gender': 'f',
#   'age': 21,
#   'country': 'United States'},
#  '91bf940ebe1f10a2206e93c5a174f64b334d4ec3': {'gender': 'm',
#   'age': 21,
#   'country': 'Russian Federation'},
#  'c22c6b6d64889f7a00d88b0cd7080b54bbce0ad6': {'gender': 'f',
#   'age': 15,
#   'country': 'France'},
#  'be5e4e61f30f09beb662a33828e6365bb88b81c9': {'gender': 'm',
#   'age': 22,
#   'country': 'Russian Federation'},
#  'cb22fc9e0def3c36979bfe13078bf91071cb6596': {'gender': 'm',
#   'age': 20,
#   'country': 'United States'},
#  '36ce1b88c51fa98d7a56011715e59b214587fc62': {'gender': 'm',
#   'age': -1,
#   'country': 'Germany'},
#  'e9f039771c43409b8bcd964e006e2e334d41efe3': {'gender': 'f',
#   'age': 20,
#   'country': 'Estonia'},
#  '38137444b0483cdbc9932bff64c32f3674b60875': {'gender': 'f',
#   'age': -1,
#   'country': 'Ukraine'},
#  '76f6ea57742746ccb6d718b1863fb4f9b6b8cf0b': {'gender': 'm',
#   'age': 26,
#   'country': 'United States'},
#  '6271a5a178125ab1248d50f06cfdbb8c75c8f709': {'gender': 'm',
#   'age': 27,
#   'country': 'Czech Republic'},
#  '45f3397d77ec482997ffa3e3393e14f0aa3d5e20': {'gender': 'm',
#   'age': 20,
#   'country': 'United Kingdom'},
#  'b69a9bddb54a31935c2bfc1845f17bfc35d407b2': {'gender': 'f',
#   'age': 25,
#   'country': 'United States'},
#  '12a127d9fd73407c5bdba75456378206b5726bb7': {'gender': 'm',
#   'age': 24,
#   'country': 'Turkey'},
#  '6f8433b9c7541a274925763877755eb3510afb93': {'gender': 'm',
#   'age': 20,
#   'country': 'Latvia'},
#  '995a3b38691aadb279f66cc70f2c80c6a1bd6c4b': {'gender': '',
#   'age': -1,
#   'country': 'Germany'},
#  'f76b92aa01ff27aea94e3cc198020b8b6975d987': {'gender': 'm',
#   'age': 37,
#   'country': 'Netherlands'},
#  'e39cf17d1d80aa9589cc7efa143532648c16f32f': {'gender': 'm',
#   'age': 33,
#   'country': 'United Kingdom'},
#  '51d24697998433c0b3a0d591516ac0106a124211': {'gender': '',
#   'age': -1,
#   'country': 'Canada'},
#  '28e05a2a59d785bf11eccc2150cf19913d3f6ffa': {'gender': 'm',
#   'age': 28,
#   'country': 'Austria'},
#  '7abba98c9a3d0e2ec1a7c28f866b2712c25e2ce1': {'gender': '',
#   'age': -1,
#   'country': 'United Kingdom'},
#  '1e0879b690f3072a4ef86166af5c7ea66bdc968b': {'gender': 'm',
#   'age': 20,
#   'country': 'Germany'},
#  '0a5526e234f8fa5fbe3ac5aad714c2b4335169b5': {'gender': 'm',
#   'age': -1,
#   'country': 'Spain'},
#  '0a04a77934326e4fe41e1ff74e8d70df23e2f8c6': {'gender': 'm',
#   'age': -1,
#   'country': 'Russian Federation'},
#  '357cbe316f777440a24504aaeb72e1667c296229': {'gender': 'm',
#   'age': 18,
#   'country': 'Poland'},
#  'de00e4e68acdf5ddae2389d92cbe4976b280f660': {'gender': 'f',
#   'age': 19,
#   'country': 'United States'},
#  'c73fe89c5213a508e4e055c943a829353bd9e661': {'gender': 'm',
#   'age': 20,
#   'country': 'Germany'},
#  '9b69d68df0c38cc27bbce938d5e623743ca3b052': {'gender': 'm',
#   'age': 16,
#   'country': 'United States'},
#  '22525d7bd959585c23263ecf0d7a8e12c1d7dfdf': {'gender': 'm',
#   'age': 27,
#   'country': 'United States'},
#  'ab968d2815b0e4a25d2759f74df7e0f0654b60ee': {'gender': 'f',
#   'age': 18,
#   'country': 'United States'},
#  '12fe6c859ddd4ead9d2a91bb37cb66ee707ea3cd': {'gender': 'f',
#   'age': 19,
#   'country': 'Germany'},
#  'af0c897534c69feff0f3ea02526a37d1cf864ad0': {'gender': 'm',
#   'age': 37,
#   'country': 'Germany'},
#  '3390e9699f6353e431f06f002dda2383cd0db783': {'gender': 'm',
#   'age': 20,
#   'country': 'United Kingdom'},
#  '4dd3546218c2277421ace36cb71f39bd4f310ee2': {'gender': 'f',
#   'age': 24,
#   'country': 'Poland'},
#  'd4548a777554fb4ee03e35dc57fe489b5755069b': {'gender': 'm',
#   'age': -1,
#   'country': 'United States'},
#  'a6096466ecfb0b3aac231e71ba4d126d88e4d2b6': {'gender': 'm',
#   'age': 37,
#   'country': 'Netherlands'},
#  '3a558d08e16f2e628a5810208cda477e87958eb8': {'gender': 'm',
#   'age': 27,
#   'country': 'Belgium'},
#  'd7ae7dfb8e5f86a5af2035783d68a9e563fd54c8': {'gender': 'm',
#   'age': -1,
#   'country': 'Iceland'},
#  'b2f27bd148c87152aa099d7a6dbe65e5aa17f4c2': {'gender': 'm',
#   'age': 22,
#   'country': 'Japan'},
#  'efcc40ad2cd8b6bdc89cc4e81e7033c77ee606c8': {'gender': 'm',
#   'age': 33,
#   'country': 'Turkey'},
#  'd4ce8cfbe6e6f9cb96f3d867c392785ee89de5a5': {'gender': 'm',
#   'age': -1,
#   'country': 'Italy'},
#  '6e95dcda74c939813e39d65672df9365e99a7b73': {'gender': 'f',
#   'age': 18,
#   'country': 'United States'},
#  '71c4c0b6ef1b749fb083a095289dbe3899e54b60': {'gender': 'm',
#   'age': 29,
#   'country': 'United States'},
#  'a2b9fb44be417f4f34fb34f6ff97017195f30169': {'gender': 'm',
#   'age': 38,
#   'country': 'Russian Federation'},
#  '0e3d85f640ddafeb4b435c9413aaa1adc214282d': {'gender': 'f',
#   'age': 26,
#   'country': 'United States'},
#  '6c8603966bfdeacf6cf2b8847217e79f619246ce': {'gender': 'm',
#   'age': 19,
#   'country': 'France'},
#  '49f01c6e3c83297cabc2e266fc7d5cd9a31e6c0c': {'gender': 'f',
#   'age': 16,
#   'country': 'Poland'},
#  'c6fd93ca80ae8967794919a223f1f1f3b2b6da62': {'gender': 'f',
#   'age': 19,
#   'country': 'Australia'},
#  'daa24be50832624964c4c2e95e8125a3ed73f8d4': {'gender': 'm',
#   'age': 22,
#   'country': 'Australia'},
#  '7dbbe0831ea5719179d0a8b5d5607d0c04ab54f0': {'gender': 'f',
#   'age': 22,
#   'country': 'New Zealand'},
#  '2a9cd7ed7863326a358f9d924a216aed9354d547': {'gender': 'm',
#   'age': 30,
#   'country': 'United States'},
#  '70f95037f73943c2ebdabe136cd5df7d77be0b3e': {'gender': 'm',
#   'age': 22,
#   'country': 'Brazil'},
#  'd797ad8fb3b3f6fcb7514f917cbfc1f87813d70d': {'gender': 'm',
#   'age': 29,
#   'country': 'United Kingdom'},
#  '52b16e25228d49c1500e9f3065dd60cb163cec77': {'gender': 'm',
#   'age': 37,
#   'country': 'Japan'},
#  '564f3732fa85475015d16fc7500320174e760099': {'gender': 'm',
#   'age': 41,
#   'country': 'United States'},
#  '2bf44842d35d1958ce218bd02f4fd3e0936b419a': {'gender': 'm',
#   'age': 25,
#   'country': 'United States'},
#  '69d68e17cdb0cf9f0322a8d015334763c6c79479': {'gender': 'm',
#   'age': 27,
#   'country': 'United States'},
#  '04d59df5af47a5a93f88fe5bb10726ed188d075c': {'gender': 'm',
#   'age': 35,
#   'country': 'Italy'},
#  '817cdb63de879650c19af6eec7fad6274a1147c6': {'gender': 'm',
#   'age': 20,
#   'country': 'Germany'},
#  '9e2c94a661afe77d486414c908ec74135ef4b56d': {'gender': 'm',
#   'age': 21,
#   'country': 'Austria'},
#  '9a77b6ec84cb63cee6b30a821ae577e07fed2682': {'gender': 'm',
#   'age': 17,
#   'country': 'United States'},
#  '60af6555333caa805ab19fb8f8dd7743c6e30f9f': {'gender': 'f',
#   'age': 23,
#   'country': 'Belgium'},
#  '79998f74dd55b20b93be9c53e0267b4bad47257e': {'gender': 'f',
#   'age': 22,
#   'country': 'Germany'},
#  '5fbd4680fc7e6aed2123e0036f97a2427e089105': {'gender': 'f',
#   'age': 23,
#   'country': 'Germany'},
#  '1327aa519b67aae5a96d238143b00ee684a8558b': {'gender': 'm',
#   'age': 30,
#   'country': 'United States'},
#  '0c7465f24ba51ba02c8f7af5289993484bd8979b': {'gender': 'f',
#   'age': 31,
#   'country': 'Russian Federation'},
#  '9f3c20667a88dc1520e0c7d384818546eb03b8c4': {'gender': 'f',
#   'age': 16,
#   'country': 'United Kingdom'},
#  'cd877c576bc1cf124576432992c66c30d98e2f1f': {'gender': '',
#   'age': 39,
#   'country': 'United States'},
#  '910f112a08b6a4b2d35213311dae9cde7db6159e': {'gender': 'm',
#   'age': 20,
#   'country': 'Brazil'},
#  '05f003c99105543769ea7ae9f391f4eb8740d61c': {'gender': 'm',
#   'age': 28,
#   'country': 'United States'},
#  '41fb211d1ceb3fe5f1e76565f5d4a909d6e79e6a': {'gender': 'f',
#   'age': 29,
#   'country': 'Australia'},
#  '317ac720e36610f8695f895b6d20f2e33138761e': {'gender': 'm',
#   'age': 19,
#   'country': 'Canada'},
#  'b0bb32d37db9dce3bfd63027d4e3245ee431a551': {'gender': 'f',
#   'age': 25,
#   'country': 'Germany'},
#  '8b5f2a0f23b77a61184e9f24e2d10072b726c3d9': {'gender': 'm',
#   'age': -1,
#   'country': 'Croatia'},
#  'b5a8e4195b08620d502b1859fb729edf4c88d415': {'gender': 'm',
#   'age': 35,
#   'country': 'Netherlands'},
#  '66885134f59ded40674f418a0015d237ff3e690c': {'gender': 'm',
#   'age': -1,
#   'country': 'United States'},
#  '424cd4424754bd6a141b5a402806765d1f7ec255': {'gender': 'm',
#   'age': 20,
#   'country': 'Macao'},
#  '91a9d965ab612b2a0dd014420d59df54ccfff035': {'gender': 'm',
#   'age': -1,
#   'country': 'Germany'},
#  'c9997a0b09eb4f71791a3953741b744187c610ce': {'gender': 'm',
#   'age': 18,
#   'country': 'Finland'},
#  'a0b35c6d0a2a23a232f650514ba8990bd6c3b214': {'gender': 'm',
#   'age': 18,
#   'country': 'Moldova'},
#  'cbcf7641a499e721e3caa5659d45be0b1d494752': {'gender': 'm',
#   'age': 20,
#   'country': 'United States'},
#  '537a5ce41fcc581a901cc46ab50511c5db797865': {'gender': 'm',
#   'age': 29,
#   'country': 'Australia'},
#  'a7a3b9c32e4e10362a1829fc6c38194a5524b158': {'gender': 'm',
#   'age': 29,
#   'country': 'United States'},
#  '97100172be58e542772026174c428a93c7d9ae07': {'gender': 'm',
#   'age': -1,
#   'country': 'Germany'},
#  '5cfaa83dadf39d1fba4206632a7a0789f26dd7e2': {'gender': '',
#   'age': 35,
#   'country': 'Spain'},
#  '15ab170af725559678b1d308ebeda22a2025f485': {'gender': 'm',
#   'age': 19,
#   'country': 'Mexico'},
#  '5b820150bb1ef2ed0ba3e4398849dbb23e00d0b3': {'gender': 'm',
#   'age': 30,
#   'country': 'United Kingdom'},
#  '50a64736da1aac12ca458ed7db1c330138d00d26': {'gender': 'm',
#   'age': 26,
#   'country': 'Israel'},
#  '6ab83e35100fadcb44a9ab866150134200304faa': {'gender': '',
#   'age': -1,
#   'country': 'United Kingdom'},
#  '0514d130ace886b820e0276880bf2c4f2941ae63': {'gender': 'm',
#   'age': 39,
#   'country': 'United States'},
#  'cd1fd88f8e663360527f38dc055cbad4f4e0ec60': {'gender': 'f',
#   'age': 20,
#   'country': 'United States'},
#  '0d22d682cded38a820d7c653a93360513e871ff1': {'gender': 'f',
#   'age': 22,
#   'country': 'Tonga'},
#  '21c9a196678ab3a2fdd75abd19a9f2def5877122': {'gender': 'm',
#   'age': 18,
#   'country': 'Germany'},
#  '486e89b59a8080def10ea69cb6b553ed40f0665f': {'gender': 'f',
#   'age': 21,
#   'country': 'Germany'},
#  '46b358b9d0fe1b7cf0a632c9587f7ba57fb4a6cf': {'gender': 'm',
#   'age': 23,
#   'country': 'United States'},
#  'eb50a6b2fd8732d798d694b7a062d1d8d398e3e7': {'gender': 'm',
#   'age': 18,
#   'country': 'Greece'},
#  'bbd7fda2fb3a97ae2d29e2a51dcbbdc8c3baf914': {'gender': 'm',
#   'age': 33,
#   'country': 'Australia'},
#  '84e08bf6a38e4070799908391c17edfba616ce42': {'gender': 'm',
#   'age': 26,
#   'country': 'United Kingdom'},
#  '8c1d3bd8bbf62da6e1b0b3ffa2cfeb340efbd59f': {'gender': 'f',
#   'age': 17,
#   'country': 'Sweden'},
#  '04313196546f3b2c540d623994be799fdca143e3': {'gender': 'm',
#   'age': 19,
#   'country': 'Poland'},
#  '6e5a3729f4bc2eb9183c7b777d4c2c42a14e13df': {'gender': 'm',
#   'age': 20,
#   'country': 'Sweden'},
#  '7e06590cefd4320a4d7e6df1028d2f0bdc47124e': {'gender': 'm',
#   'age': 17,
#   'country': 'Sweden'},
#  '7761df92740e8bdaed77c83050e90a7187675ce1': {'gender': 'm',
#   'age': 24,
#   'country': 'Australia'},
#  'b65525302b9dc3c1aa5a9938fb45bfa8017b1615': {'gender': 'm',
#   'age': 21,
#   'country': 'Romania'},
#  '539a8fc61fb6f26da0ece86caf869a94342667e5': {'gender': 'f',
#   'age': 23,
#   'country': 'Latvia'},
#  '2a361b5e39d6a7dacefa7c8858cf9bd2efec4d9c': {'gender': 'm',
#   'age': -1,
#   'country': 'Japan'},
#  '608fbd89a4eee0e101823d9ee7d17fdeb55e9892': {'gender': 'm',
#   'age': 17,
#   'country': 'Germany'},
#  '7e16b53581df4c4766cec7341dbecbcd0aa9f860': {'gender': 'f',
#   'age': 24,
#   'country': 'Belgium'},
#  'acbc86feec1e09b69bbf546891a8227f4952ff67': {'gender': 'm',
#   'age': 20,
#   'country': 'Russian Federation'},
#  '5826d5525d6992effa456bdc3cb98a629ad3ff7f': {'gender': 'm',
#   'age': -1,
#   'country': 'Mexico'},
#  '1e50cf723c2032aa08930d114e829a3026cc39dd': {'gender': 'm',
#   'age': -1,
#   'country': 'Cape Verde'},
#  '93526583f1c37566c162b643aecd5b0b7d881b9b': {'gender': 'm',
#   'age': 26,
#   'country': 'Russian Federation'},
#  '3007118648f0c125062747146d649a12ae9cebec': {'gender': 'f',
#   'age': 18,
#   'country': 'Norway'},
#  'db4bbcf10cb9612c34121d0ba8d96052a393098c': {'gender': 'f',
#   'age': -1,
#   'country': 'Canada'},
#  'ab4cc9aa3d9367d2a518f2979c7fcf5cb0d55d7f': {'gender': 'm',
#   'age': 22,
#   'country': 'United States'},
#  'e085da7bf5044f60f0555a569b4c3f82ef65c901': {'gender': 'm',
#   'age': -1,
#   'country': 'United Kingdom'},
#  '322392d0c6351b78bccb977d49727c97b50d72a4': {'gender': 'm',
#   'age': -1,
#   'country': 'Japan'},
#  '01d4a689a77a13e60ea7166c4e94c7c5dc69e978': {'gender': 'm',
#   'age': 23,
#   'country': 'Bulgaria'},
#  '948ba01075fac4aa78f142a3e120d5de61a1be76': {'gender': 'm',
#   'age': 30,
#   'country': 'Spain'},
#  'f0acfb286b1efef5d8ea0cd38e953bdc1eacdc53': {'gender': 'f',
#   'age': -1,
#   'country': 'Bulgaria'},
#  'b202e5c8f635d870dfd5b0ef993990d43e3a6a61': {'gender': 'm',
#   'age': 23,
#   'country': 'Germany'},
#  'dfa7a9284802e2702fa3085da41748dab853bc96': {'gender': 'm',
#   'age': -1,
#   'country': 'United States'},
#  '74f6da8a878ae43cb7c12ebc292c67c9f68fb7b6': {'gender': 'm',
#   'age': 31,
#   'country': 'Brazil'},
#  '190516650d062ef0ded44e340364d95c19b8a95d': {'gender': 'm',
#   'age': 16,
#   'country': 'Italy'},
#  '5023984e266e5724d40e0cc24c0efe4f38651718': {'gender': 'm',
#   'age': -1,
#   'country': 'United Kingdom'},
#  '78b5fcedba792c97c30e4696e7a1ec5c4b8df299': {'gender': '',
#   'age': -1,
#   'country': 'Russian Federation'},
#  'a4ac39b23479e7e1196a156394ed3cd12013b176': {'gender': 'm',
#   'age': 26,
#   'country': 'Sweden'},
#  '839296c545c42dc8d39bdc9f953fca7a3a080e34': {'gender': 'm',
#   'age': 27,
#   'country': 'Russian Federation'},
#  'f29dd15b8567c0829d2e6b32d9d507f45f864012': {'gender': 'f',
#   'age': 22,
#   'country': 'Mexico'},
#  'd5fe878c91ef4f9eae333c1e6a8d5513b93a2b96': {'gender': 'm',
#   'age': 30,
#   'country': 'Czech Republic'},
#  '0439d6bcdb9555f2baf8d021ef7ef3d2fe170eea': {'gender': 'm',
#   'age': -1,
#   'country': 'United States'},
#  'ec0f3f634aac325e81365801d4632bba5386bbbf': {'gender': 'm',
#   'age': -1,
#   'country': 'Finland'},
#  'f64f33bcff2b324fc197febd1d7438556b3aa31c': {'gender': 'f',
#   'age': 22,
#   'country': 'United Kingdom'},
#  'b1157bda943bc7fa95530d63f7010357a6bc307b': {'gender': 'm',
#   'age': 22,
#   'country': 'Germany'},
#  'beb3ce334bcb470f75a079182c277151ab8238d2': {'gender': 'f',
#   'age': 26,
#   'country': 'United Kingdom'},
#  '5003f745cfda4ad98efbcc2414287a4996192ce0': {'gender': 'f',
#   'age': 30,
#   'country': 'United Kingdom'},
#  '8a5d725f016cfc484e7a155e58a233c158509301': {'gender': 'm',
#   'age': 26,
#   'country': 'Greece'},
#  '6504efa7147b73470c617595e29e77249c57cca9': {'gender': '',
#   'age': -1,
#   'country': 'Germany'},
#  '2b77f608957536ad622b96a1ca512621bef4a26e': {'gender': '',
#   'age': -1,
#   'country': 'Japan'},
#  'ff441452d423999e6e8a66d144af632fc679db15': {'gender': 'm',
#   'age': 22,
#   'country': 'United Kingdom'},
#  '4d993942845eb6b59dcbe7ec38ad533e486c6cb9': {'gender': 'm',
#   'age': 29,
#   'country': 'Netherlands'},
#  '804b009a8477813de3e86ea425153bf53c2d0471': {'gender': 'm',
#   'age': 18,
#   'country': 'United Kingdom'},
#  '2b9349949f0156a8ff307d2797f4cebafb39b5d5': {'gender': 'm',
#   'age': 16,
#   'country': 'United States'},
#  '64a34c8ce04d6cd4b0444ce66f1ed5ae906abf1a': {'gender': 'f',
#   'age': 55,
#   'country': 'Belgium'},
#  'dfd32b69be07de1aa9dc60567abaed0210f749cc': {'gender': 'f',
#   'age': 24,
#   'country': 'United States'},
#  '1f86b1a7379cf29e21e75b0d8a870a775d04a6e4': {'gender': 'm',
#   'age': 19,
#   'country': 'United States'},
#  '65fd5161744c1762b396d68a907a6e671be154e1': {'gender': 'm',
#   'age': 22,
#   'country': 'Bulgaria'},
#  'b46f7ee9dd0635c127b50e958e9b719313195c08': {'gender': 'm',
#   'age': -1,
#   'country': 'United States'},
#  '449c951893984c631a4b2de8d8657179743d531c': {'gender': 'm',
#   'age': 22,
#   'country': 'United Kingdom'},
#  'a3f4e2c95c1363772f751abe2cd79a23009d6c29': {'gender': 'f',
#   'age': 20,
#   'country': 'Brazil'},
#  'cf36c405a8fc0570816b14cec333ad046a1cee88': {'gender': 'f',
#   'age': 20,
#   'country': 'United States'},
#  '1abf9da6100e943d40083ae3437086ca0de08999': {'gender': 'f',
#   'age': 22,
#   'country': 'Turkey'},
#  'acb9c302ecd352581cf020fd0ebf9c73ce2c77f6': {'gender': 'm',
#   'age': 21,
#   'country': 'Slovenia'},
#  '6acee6678ede7490a1cfe7184598d2479630e568': {'gender': 'm',
#   'age': 25,
#   'country': 'Serbia'},
#  '539c605736a345a9d9e73cef4082e70c214a642b': {'gender': 'm',
#   'age': 25,
#   'country': 'United States'},
#  '66fda55ad89ae5e2c0c8c3c6930f24c861e6fbf9': {'gender': 'f',
#   'age': 16,
#   'country': 'Poland'},
#  'd3b4046b7c41a912bad33c14ce12018ae9b9ebf7': {'gender': 'f',
#   'age': 16,
#   'country': 'Germany'},
#  'fd26dab961a7d48b0d86e49a1e4fe31d99f54c39': {'gender': 'f',
#   'age': -1,
#   'country': 'Poland'},
#  '19bd1a1d655f280d51be3afd192af372db323684': {'gender': '',
#   'age': 35,
#   'country': 'United States'},
#  '69bcd46c46d9b5b23859f13bc54a48c027525ad7': {'gender': 'm',
#   'age': 21,
#   'country': 'United Kingdom'},
#  '34d81152d1eb98b2c527cf1393fe0e3ae872571b': {'gender': 'm',
#   'age': 19,
#   'country': 'United Kingdom'},
#  '94cd624ea34d8ad83a78c821b88359a615f927b0': {'gender': 'f',
#   'age': 21,
#   'country': 'United States'},
#  '72a8e19fc94821abb22c6d9b3af6996b9e560ca3': {'gender': 'm',
#   'age': 23,
#   'country': 'Latvia'},
#  '243cc0461894fd132b46978750dc488ac546215b': {'gender': 'm',
#   'age': -1,
#   'country': 'United Kingdom'},
#  '35cd23a1a277105eaa667793335ceeee6fa41c78': {'gender': 'm',
#   'age': 33,
#   'country': 'Spain'},
#  'f0473b07241c276066f6d94981f4229833fbcfed': {'gender': 'm',
#   'age': 17,
#   'country': 'Denmark'},
#  '88cd39f26d437f0bcc762a5b6edb4497eed42b19': {'gender': 'f',
#   'age': -1,
#   'country': 'Netherlands'},
#  '22f5661f1cb6b2f0753c35ea2f1f3798c7d546df': {'gender': 'f',
#   'age': -1,
#   'country': 'United Kingdom'},
#  '3565a1ac8cce089dc7746b8a20d9d244cbe85f81': {'gender': 'f',
#   'age': -1,
#   'country': 'Myanmar'},
#  '3a5ba344f66acb11b87bbf62ec80254d76c47b53': {'gender': 'm',
#   'age': 21,
#   'country': 'Canada'},
#  '53d911efb0ab212e179d80d8a0a9e0c5775d5086': {'gender': 'm',
#   'age': 24,
#   'country': 'Australia'},
#  'a8990997ff82c4eaaa721c8a52102413eaa2b099': {'gender': '',
#   'age': 17,
#   'country': 'Germany'},
#  'f050e5f9622bde8805b753a931c9c0f9bb329dff': {'gender': 'm',
#   'age': 19,
#   'country': 'Russian Federation'},
#  'e345f6af189591409c339e1cbfbf093e3c15e33d': {'gender': 'm',
#   'age': -1,
#   'country': 'United States'},
#  'f728f64e1c625ce33c8c4cd018b3959f7c65e802': {'gender': 'm',
#   'age': 24,
#   'country': 'United States'},
#  '07fd62a3753fdd3da25a1e5e63e8c3a29f9af3df': {'gender': 'm',
#   'age': 21,
#   'country': 'Slovenia'},
#  '5abe1bc33733b7b5d2baee15fbaec1cbfa507931': {'gender': 'f',
#   'age': 18,
#   'country': 'Australia'},
#  '2ce61f00ea1104a749fe457b97933bba225bab25': {'gender': 'f',
#   'age': 27,
#   'country': 'United States'},
#  'f41ceacf0d1822664a67d06ebbb076e4faead206': {'gender': 'm',
#   'age': 26,
#   'country': 'Argentina'},
#  'edf87d5cac6ce65fe0b2a5c3d29c253e1871f532': {'gender': 'm',
#   'age': 71,
#   'country': 'United Kingdom'},
#  '5623f22cc3054d7c35ce14b3141a70957192d33b': {'gender': 'm',
#   'age': 25,
#   'country': 'Croatia'},
#  '7a71ab9700c64fa48808a943b7f862676e875918': {'gender': 'f',
#   'age': 23,
#   'country': 'United States'},
#  '58aa49c32b3f19d2ec7d46d4746a1a1b5cd0ee9c': {'gender': 'm',
#   'age': -1,
#   'country': 'United States'},
#  '48b901fef262ce9caaf0ecc5c093871f39385875': {'gender': 'm',
#   'age': 25,
#   'country': 'Portugal'},
#  '4e38f14abfddd875841811cf334dbbbcc260a644': {'gender': '',
#   'age': 27,
#   'country': 'Poland'},
#  '73031cf84dbb87da603b3a7598b4b484465abaf6': {'gender': 'm',
#   'age': 24,
#   'country': 'Croatia'},
#  '2a68e1305babda41d9f9094a4c9412479b56dac4': {'gender': 'm',
#   'age': 24,
#   'country': 'Portugal'},
#  '76fedd7853e100dfc793d6e95d8bdfa30c273c8d': {'gender': 'm',
#   'age': 26,
#   'country': 'United States'},
#  'c7621e47a86bdefc654f86d52926210d906544b2': {'gender': '',
#   'age': 26,
#   'country': 'United States'},
#  '770251a7c3c32de8bb9aa9e208e17d49c3b0f4d5': {'gender': 'm',
#   'age': 22,
#   'country': 'Brazil'},
#  'd13acb1c73bd9389f4efaf2239cc3e93daa5162e': {'gender': 'm',
#   'age': 26,
#   'country': 'United States'},
#  '4658788db6124f08f85b47e920ab36f0b44c04c4': {'gender': 'm',
#   'age': 29,
#   'country': 'Netherlands'},
#  '669da66fc1d092551fd99ba60359474273d46e5b': {'gender': 'f',
#   'age': 21,
#   'country': 'Macedonia'},
#  '1517902a09b59ef6912faab2ec616ffdfbc729cb': {'gender': 'f',
#   'age': 23,
#   'country': 'United States'},
#  'e94243652ff52a2f0b043d2a68b6b145f85c578a': {'gender': 'm',
#   'age': 18,
#   'country': 'Austria'},
#  'c29ccff51287b3be0785579e8c57a954d3422e86': {'gender': 'm',
#   'age': 19,
#   'country': 'Brazil'},
#  'd4424ad18d681a02226ea9b906fb4df079fb3846': {'gender': 'm',
#   'age': 21,
#   'country': 'Russian Federation'},
#  'f6a30a85d1d9159ee34afd29bb61ce1bdf80e8a2': {'gender': 'f',
#   'age': 29,
#   'country': 'Bosnia and Herzegovina'},
#  '8ce01375fa1b0fa690f100bc922c6742a563b234': {'gender': 'm',
#   'age': -1,
#   'country': 'Russian Federation'},
#  '333b81fa1696385232cf794bf935e1f5ef2de86c': {'gender': 'm',
#   'age': 35,
#   'country': 'United Kingdom'},
#  '9bf13350a0eb8107bc4e42ff4d805feaadf17b49': {'gender': 'm',
#   'age': 31,
#   'country': 'United States'},
#  '0ef83cf01e4ca49f77d37e651bfe05623f3304e7': {'gender': 'f',
#   'age': 16,
#   'country': 'Poland'},
#  '0a7005b75925611376e842c1326742e813ef5e5c': {'gender': 'm',
#   'age': 16,
#   'country': 'Poland'},
#  '5abc4d9ac46ddd82ba5e1e3a148cf4f13807fd44': {'gender': 'm',
#   'age': 25,
#   'country': 'Mexico'},
#  'c891918b46592c09af7c74af81b4122b7039e68d': {'gender': 'm',
#   'age': 34,
#   'country': 'United Kingdom'},
#  '3b4d2849db2bdd700179b34349389429f46dcf9a': {'gender': 'm',
#   'age': -1,
#   'country': 'Norway'},
#  'a7341e8f6e75f371478710b7396a5dcce6d2d293': {'gender': 'm',
#   'age': 21,
#   'country': 'Spain'},
#  '06cfc717e0a7f22dd1326d433bfb2baf6c5ed299': {'gender': 'f',
#   'age': 22,
#   'country': 'United States'},
#  '69e58bbf5359be56e40cc5d5dac0208363813720': {'gender': 'f',
#   'age': 16,
#   'country': 'Germany'},
#  '8407adcc8e3a26e7ad356cbe89ef22a2cb8b298b': {'gender': 'f',
#   'age': 20,
#   'country': 'Poland'},
#  'e507fdc86dc02c43de23ba85788306a0898bcf45': {'gender': 'm',
#   'age': 22,
#   'country': 'United States'},
#  '9e1dff2888ba0187d07fc8d570d10b3b31bda73a': {'gender': 'm',
#   'age': -1,
#   'country': 'Finland'},
#  'b1c95efbe7c3e96fa1c153dd63893f34ba46745c': {'gender': '',
#   'age': -1,
#   'country': 'Germany'},
#  '279709f51273183c2105fb722924938be3b065aa': {'gender': 'f',
#   'age': 31,
#   'country': 'United States'},
#  '4e3f4f9914044bf6f4ca44e816631db36d0dff47': {'gender': 'm',
#   'age': 31,
#   'country': 'United Kingdom'},
#  'c328cd3012d08ce20ab1d944ef80a404df7c0bcc': {'gender': 'm',
#   'age': 20,
#   'country': 'Russian Federation'},
#  '60da4f8fd6e17d1056407fb67c870d6f11bdad08': {'gender': 'f',
#   'age': 23,
#   'country': 'Poland'},
#  'b40bd6f0a8e35944c55eb531c16d396dff2b3701': {'gender': 'm',
#   'age': 19,
#   'country': 'United States'},
#  '96bd5a91e5880b62b546cfafddc147255128abcf': {'gender': 'm',
#   'age': -1,
#   'country': 'Spain'},
#  '1695fd110f94a40d54d8809bbeee497098abb903': {'gender': 'm',
#   'age': 54,
#   'country': 'Belgium'},
#  'a17b3e3a82ddff265940446fb4efbab9113bae66': {'gender': 'm',
#   'age': 26,
#   'country': 'Poland'},
#  '69d2c3d98fdf7fba50880b1df63c82e234f16e78': {'gender': 'm',
#   'age': 23,
#   'country': 'Russian Federation'},
#  'e2202bb4ae1abbfec916fc5148db3f41c86ff212': {'gender': 'm',
#   'age': 31,
#   'country': 'Brazil'},
#  '4078e2b647119658a2fe9840d2fb1008bd79d604': {'gender': 'm',
#   'age': 35,
#   'country': 'United States'},
#  'dd7e5fdcde9c5bba70109be88409e52584497186': {'gender': 'm',
#   'age': 25,
#   'country': 'Switzerland'},
#  'ddc6be721b21a1ee1e1de942f95c04f83fe5116c': {'gender': 'm',
#   'age': 30,
#   'country': 'United States'},
#  '22e12ce93b677abe3b3b0e2f85e98b2a269abc84': {'gender': 'm',
#   'age': 23,
#   'country': 'Spain'},
#  'bfb0c7dc4b5212ef3bc77c591c4e108b6e2a3887': {'gender': 'm',
#   'age': 22,
#   'country': 'Poland'},
#  '0209d80c7d6207cac83e5acb5db1589f25c94bef': {'gender': 'm',
#   'age': 30,
#   'country': 'United States'},
#  '03a3657e09d6f047fc0ac89707fadc21015a9cfa': {'gender': 'm',
#   'age': 29,
#   'country': 'United States'},
#  '4d54d8a49279395856f20d613931a9b9ceaa265e': {'gender': 'm',
#   'age': 22,
#   'country': 'United States'},
#  'c94f58eb7051e0cbd45c28d3ffa30046b7bd6e80': {'gender': '',
#   'age': 24,
#   'country': 'Canada'},
#  'ca8fe27de6b188d9190f3ece36fdfea003796208': {'gender': 'm',
#   'age': 17,
#   'country': 'Brazil'},
#  '909931a7a00885faaa355d421526c2571f3180e3': {'gender': 'm',
#   'age': -1,
#   'country': 'United States'},
#  '2218f41d9da0ce1ceb9b9de6916f96b0f4c9b631': {'gender': 'm',
# ...
#  'ab066452f6eef6dec7e8aab22fdfbaef432a0ff2': {'gender': 'm',
#   'age': -1,
#   'country': 'Netherlands'},
#  '109229b31c9b5a5bdf125fc7b987db39bf4f8af1': {'gender': 'm',
#   'age': 27,
#   'country': 'United States'},
#  '8079f16aa8b6ebee16546eadb02eed878f6437c4': {'gender': 'm',
#   'age': 39,
#   'country': 'United States'},
#  '582ca8a399fb4960110da92ab84f4082d5321e2a': {'gender': 'f',
#   'age': 27,
#   'country': 'United States'},
#  '45da4c9ab6b5ea0e2758070f48ac75a358655552': {'gender': 'm',
#   'age': 20,
#   'country': 'Bulgaria'},
#  '229c541a9de90a2adb501dfd90e1f2228ec8a974': {'gender': 'f',
#   'age': 21,
#   'country': 'Russian Federation'},
#  '8996f921ddad5fd0a085051822485290dca6b709': {'gender': 'm',
#   'age': 19,
#   'country': 'Mexico'},
#  '08a09200019d1fa6136b869430a99a3736247b56': {'gender': 'm',
#   'age': 25,
#   'country': 'Russian Federation'},
#  '223bff7ae8522f076ea12b7e13776e5d32c316ed': {'gender': '',
#   'age': 61,
#   'country': 'United States'},
#  'cb9f52eaf504f3ccd887d64b3c87858003c8e1bc': {'gender': 'f',
#   'age': 33,
#   'country': 'Spain'},
#  '42099cf1aa07991209f220e7f676e241bc415a9c': {'gender': 'm',
#   'age': 21,
#   'country': 'Belarus'},
#  '98c2ff49af8f8cd803a01b446e3224b30de4306a': {'gender': 'f',
#   'age': 21,
#   'country': 'Russian Federation'},
#  'e7898c063bd018fe241d013ee9cabef9ae148159': {'gender': 'm',
#   'age': 16,
#   'country': 'Sweden'},
#  'c270e3da40e4ae6746b574d78ac270cad82d0651': {'gender': 'f',
#   'age': 18,
#   'country': 'United Kingdom'},
#  '298468083853335477465bf6e520615453cf053e': {'gender': 'm',
#   'age': 22,
#   'country': 'United Kingdom'},
#  'a701702a5007653e5fca4da1f8e4f0c5e48b6da7': {'gender': 'm',
#   'age': 19,
#   'country': 'United States'},
#  '835faada0ff5d0b1f3a2ac0ea54f13a55cb68213': {'gender': 'f',
#   'age': 15,
#   'country': 'United Kingdom'},
#  '33310f347e04713475a44ee111b5a8198acbc55d': {'gender': 'f',
#   'age': 33,
#   'country': 'Russian Federation'},
#  '2ad74cbbe1f0b0f10f66d315c49889311b7128df': {'gender': 'm',
#   'age': 23,
#   'country': 'France'},
#  'f1a9fbbd2b92523fd45c2caf5ca0461321720196': {'gender': 'm',
#   'age': 20,
#   'country': 'Finland'},
#  'd4fffe3154ab243cd7b1ef2877454efe1552dfd8': {'gender': 'm',
#   'age': 26,
#   'country': 'Sweden'},
#  '69169c993996e85cca6e68875a20daea18462fe8': {'gender': '',
#   'age': -1,
#   'country': 'Finland'},
#  '04cf8b5e6e0c828bd60257c8758d879491b50574': {'gender': 'm',
#   'age': 23,
#   'country': 'Latvia'},
#  'b271b845ab8aa10035ffeb3e88b5efef3a720897': {'gender': 'm',
#   'age': 28,
#   'country': 'Poland'},
#  'bbd1f0e65b0ff5e45301887171abb36303ad33ee': {'gender': 'm',
#   'age': 26,
#   'country': 'Poland'},
#  'ec30c4cb2c3ab00a5bebf407989b078b3f3deb65': {'gender': 'm',
#   'age': 22,
#   'country': 'Belgium'},
#  'af93d5e84de7f0b3ad66b984fd80cf13071a52a8': {'gender': 'm',
#   'age': 34,
#   'country': 'United Kingdom'},
#  'd94e3e57e94bf9ee059e4fc85c8ffdb51838c57f': {'gender': 'f',
#   'age': -1,
#   'country': 'United States'},
#  '97ea4961cc3d2754d785d873c75ec961c0a036d2': {'gender': 'f',
#   'age': -1,
#   'country': 'Denmark'},
#  'e38b05cd7e8ac519db3a3deb66c56355dad09b5c': {'gender': 'f',
#   'age': 20,
#   'country': 'United States'},
#  'bf2cb1da14ace9880d2087f472944203fc0ede2a': {'gender': 'f',
#   'age': 21,
#   'country': 'Denmark'},
#  'f4eb1a1a7bc79ab64cb3ab7c30c618542b219d31': {'gender': 'm',
#   'age': -1,
#   'country': 'Netherlands'},
#  'a739419f88c693697577b09fb83353083db89fc4': {'gender': 'm',
#   'age': -1,
#   'country': 'Germany'},
#  'ff799e44fac8822005054f53cf901410a085b33f': {'gender': 'm',
#   'age': 35,
#   'country': 'Macedonia'},
#  '208427c00de813fcbe89891225b7dd38ed53c3f6': {'gender': 'm',
#   'age': -1,
#   'country': 'Belgium'},
#  '9980a621dbb1abc11a0d77739480723bfbb1d775': {'gender': 'f',
#   'age': 24,
#   'country': 'United States'},
#  '3cc1b7a5cdcf7f4cfe721c107cccc1d55de1ed5d': {'gender': 'm',
#   'age': 15,
#   'country': 'Belgium'},
#  '817f8a4547ba059974beef5cd76b11a855b4e576': {'gender': 'm',
#   'age': -1,
#   'country': 'Australia'},
#  '63575992543cffbd0ebaf68a14b250804917e27f': {'gender': 'm',
#   'age': -1,
#   'country': 'Germany'},
#  '2af57545006ac68952d4c9fb593313e029017d36': {'gender': 'm',
#   'age': -1,
#   'country': 'Poland'},
#  'eecb12fcae36b4a20c4ab92f5488b2b0caeefa86': {'gender': 'm',
#   'age': -1,
#   'country': 'Slovenia'},
#  '0670ee141ba500d2dd48db95b46b3858ab73c753': {'gender': 'm',
#   'age': -1,
#   'country': 'Spain'},
#  'a066366742eb1a58db69c68b607c15813e6118b5': {'gender': 'm',
#   'age': 28,
#   'country': 'Australia'},
#  '2d3f7cd55aa9a76e3d78df895d899768680321d0': {'gender': 'm',
#   'age': 15,
#   'country': 'Latvia'},
#  'a4146c86cc8a87ee915519ff51d5c2a35041617c': {'gender': 'f',
#   'age': 19,
#   'country': 'Hungary'},
#  '383eb4ed18e2a5eed3a573a2799906c32088a238': {'gender': 'm',
#   'age': 37,
#   'country': 'Russian Federation'},
#  '8e248402a513b5a5353e5aec968fcb155a194b99': {'gender': 'm',
#   'age': 23,
#   'country': 'Australia'},
#  'af8342b6337072667889a8158aee7e47dc26919d': {'gender': 'f',
#   'age': 27,
#   'country': 'United States'},
#  '48127262edca3eab8fb1a79f3ff40601f46b8de5': {'gender': 'm',
#   'age': 22,
#   'country': 'United States'},
#  'c6a1f110061f843fff8a0d123bd7cb0d2d5f1e50': {'gender': 'm',
#   'age': 45,
#   'country': 'France'},
#  'e3d5e0d9bff94c508a55dc43ccd2453036040072': {'gender': 'm',
#   'age': -1,
#   'country': 'Spain'},
#  'f366f0f745a0ee39e6171c5c0ce7772f534766be': {'gender': 'm',
#   'age': -1,
#   'country': 'France'},
#  '4963773df34134e0530a06e730bc809ae60c9d38': {'gender': 'm',
#   'age': -1,
#   'country': 'Spain'},
#  '15d0e54d7e579330593b9584ece545263e49bf19': {'gender': 'f',
#   'age': 17,
#   'country': 'Belgium'},
#  '12624816ddd478a4d3a37174ec2f89b7352ac3bd': {'gender': 'f',
#   'age': 24,
#   'country': 'Poland'},
#  'e4e3719a20d073c1ef6b9d69a2b659ef90376785': {'gender': 'm',
#   'age': -1,
#   'country': 'United States'},
#  'bce9156f3bb444fa8c0adcdf4c74f908397796fd': {'gender': '',
#   'age': -1,
#   'country': 'United States'},
#  '3d8c01fb93ad9fa4067140779134fa7705c56738': {'gender': 'f',
#   'age': 22,
#   'country': 'Brazil'},
#  '59b593ce2a71715b5432995a843af52bfb092d34': {'gender': 'm',
#   'age': 25,
#   'country': 'Australia'},
#  '5c8a7c124a1a5c5504ae2e79ca35556bec236b3d': {'gender': 'm',
#   'age': 20,
#   'country': 'Russian Federation'},
#  'c9b4510e93d8b581e0524a1dd5b04b40bb80ee80': {'gender': 'm',
#   'age': 21,
#   'country': 'United States'},
#  '2167b59dbb0afbc29f5cc6dae971b9a51a539d60': {'gender': 'm',
#   'age': 17,
#   'country': 'United States'},
#  '5a89f01dd9837b2b48d7b49475417a86b5a377d4': {'gender': '',
#   'age': 20,
#   'country': 'United States'},
#  '9bdabcdd6c978aa3b743b2bae10700d2d0e988fc': {'gender': 'f',
#   'age': 24,
#   'country': 'Mexico'},
#  '90f9148e7d39f91f432761845da2822e660508d0': {'gender': '',
#   'age': -1,
#   'country': 'United Kingdom'},
#  '24985044d7db18a0dc6e3133b154b4b1a11e9ec0': {'gender': 'm',
#   'age': 30,
#   'country': 'Portugal'},
#  '3b9e451a5d7e6c18459bcbefc1d75e0c682b5930': {'gender': '',
#   'age': -1,
#   'country': 'Netherlands'},
#  'f5c60d7d2e942e5a5c8a4e5ed96b6861383c4b00': {'gender': 'm',
#   'age': 25,
#   'country': 'Venezuela'},
#  '8d21fb1243b436c4eefc7c148ec751e88654f83a': {'gender': 'm',
#   'age': 27,
#   'country': 'Switzerland'},
#  'e6b5d48afa4f0d43b91c49f9027385a3e75280c7': {'gender': 'f',
#   'age': -1,
#   'country': 'Romania'},
#  '6362c06872a1d59739eafc196a9d79e87d466464': {'gender': 'm',
#   'age': -1,
#   'country': 'Germany'},
#  'e4ec0fee2569f54a4af174a7f2363ff456e6b32e': {'gender': 'm',
#   'age': 26,
#   'country': 'Latvia'},
#  'fa3a45c4025f1259767baa3cbaf37508de7b231f': {'gender': '',
#   'age': 18,
#   'country': 'Mexico'},
#  'f6f549407e71cdde08a81d8cb4f4f8ef45670a5a': {'gender': 'm',
#   'age': 23,
#   'country': 'Germany'},
#  '09d5ba9d6203569e8d804ce73eef482c4296bbf4': {'gender': 'f',
#   'age': -1,
#   'country': 'Canada'},
#  '0b8bf6bc8f71dd6babc7dca5222f07ab0b6d1e17': {'gender': 'm',
#   'age': 28,
#   'country': 'Sweden'},
#  'ccdce7c8fe7fbd13397f2d4910c0c430458fff0b': {'gender': 'm',
#   'age': 21,
#   'country': 'United States'},
#  '4eb0387272041914fdca9453e45a325ef2b5879d': {'gender': 'm',
#   'age': 31,
#   'country': 'Germany'},
#  '0a72e5e5466544278efdf2a9f882d997bd67a9ae': {'gender': '',
#   'age': 26,
#   'country': 'France'},
#  '5ab2a85c36c0101dd233b460e9e93cdecac9a5af': {'gender': 'm',
#   'age': 28,
#   'country': 'United States'},
#  'f64520c7428843ada801f31b4e2bd25f0ec21add': {'gender': 'm',
#   'age': -1,
#   'country': 'Czech Republic'},
#  '037095642c70750ae41dae9221039618a883fd5c': {'gender': 'm',
#   'age': 31,
#   'country': 'Sweden'},
#  '23fd4acf053292a90a3dc67527c8d4c4da424205': {'gender': 'f',
#   'age': -1,
#   'country': 'Germany'},
#  'e5d70276a982e53bca2f7cf2cebe6684e8d2cef7': {'gender': 'm',
#   'age': 19,
#   'country': 'Sweden'},
#  '7628b7581e58d501fa4fc60bdd7405e17d61a830': {'gender': 'f',
#   'age': -1,
#   'country': 'United States'},
#  '48af4b2216b1435cde8ffb4e879bb4b9c1a525f4': {'gender': 'f',
#   'age': 41,
#   'country': 'Germany'},
#  'f5a03776ca62334f26af342c6378160235769308': {'gender': 'm',
#   'age': 44,
#   'country': 'Norway'},
#  'fdb0784efcfa82d5a953d36e44287179efe53ab1': {'gender': 'm',
#   'age': 28,
#   'country': 'United Kingdom'},
#  'c28ae8be12277b72bba254497cb165051b3d215a': {'gender': 'f',
#   'age': 19,
#   'country': 'United States'},
#  'e0bc8d60ea27a3fed2f133c13514cbd0e6cede03': {'gender': '',
#   'age': 21,
#   'country': 'Indonesia'},
#  'c659349f7ed0a0b8838fd53fe70916172918fbb4': {'gender': 'm',
#   'age': 109,
#   'country': 'United States'},
#  '3924750dbbb9f2e33089b71e61200a19db246ab7': {'gender': 'm',
#   'age': 23,
#   'country': 'United States'},
#  '9345ce1792edbe17e014bd076bf9214a3913611b': {'gender': 'm',
#   'age': -1,
#   'country': 'Netherlands'},
#  'f204b70136c7a978cb0241bb47949ca7b87b21d6': {'gender': 'f',
#   'age': 20,
#   'country': 'Finland'},
#  '2c1509cc23da07f057a81e6c3f28de071ac66ce0': {'gender': 'm',
#   'age': -1,
#   'country': 'Canada'},
#  '46db6e0cc5c690a1c25aa7a144cdeb1772652f94': {'gender': 'm',
#   'age': -1,
#   'country': 'United States'},
#  'bd790ffeec0b65d8b47c537674e6638bfabea68c': {'gender': '',
#   'age': 22,
#   'country': 'United States'},
#  'b5b5856118a3a6bb0a84f15335f62abbce2ecb02': {'gender': 'f',
#   'age': 20,
#   'country': 'United Kingdom'},
#  'e8a66f6d3ca3ab1c44c940c7375c1173d52b1dbc': {'gender': 'f',
#   'age': 30,
#   'country': 'United States'},
#  '98a94a1a31a3ed89fc5dd779a0b65550c9e3d0f8': {'gender': 'f',
#   'age': 23,
#   'country': 'Czech Republic'},
#  '6bb4663cec835c1b9ede63e5f8b8132f06ca652c': {'gender': 'm',
#   'age': 25,
#   'country': 'United States'},
#  'a9f6ab56e96d5013c67b70c9b00f4db1a67bbec1': {'gender': 'f',
#   'age': 41,
#   'country': 'Norway'},
#  'e667e52b07456700da39064b761aaa37123d9f4d': {'gender': 'm',
#   'age': -1,
#   'country': 'Germany'},
#  '1744a6f442a6ea410276a165e870154516a942ef': {'gender': 'f',
#   'age': 20,
#   'country': 'Poland'},
#  '3fad136bb9eca650d67b463edac864e9781b674c': {'gender': 'm',
#   'age': -1,
#   'country': 'United States'},
#  '7e0bf455d68012e9f79a37ce028966dfbd662735': {'gender': 'm',
#   'age': 56,
#   'country': 'Germany'},
#  'a462bd2c3adc76f174ecaddd06720f2f3b30c16b': {'gender': 'f',
#   'age': 22,
#   'country': 'United States'},
#  'fec9c33bbb3ee318f8de42238b889a280220522f': {'gender': 'm',
#   'age': -1,
#   'country': 'United States'},
#  '8099e7e50bdfc5a8e83e244f1c6a99c54c3e07c7': {'gender': 'm',
#   'age': 25,
#   'country': 'Czech Republic'},
#  'def0fdf135a15e6efb26a6f055cee6f145d51035': {'gender': 'f',
#   'age': -1,
#   'country': 'Finland'},
#  'ed209d795d57d32174a1e1a8cf329ba3aa528e3f': {'gender': 'm',
#   'age': 2,
#   'country': 'United States'},
#  'd804536281137300dcc267cd92a1b75e628d26b1': {'gender': 'm',
#   'age': 18,
#   'country': 'Austria'},
#  '32d6e9d2bef5234e926abb2ae80beaccae11612c': {'gender': 'm',
#   'age': 19,
#   'country': 'United Kingdom'},
#  'ddbc508c307b7c73c576a33687a340e7c17e2d55': {'gender': 'm',
#   'age': 108,
#   'country': 'Burkina Faso'},
#  '254f9b389eb0ea731bd490c07855801aa420545f': {'gender': 'f',
#   'age': 24,
#   'country': 'Russian Federation'},
#  '2f134fa17eff6d75eebf7be8a8c947b33618c754': {'gender': '',
#   'age': 38,
#   'country': 'Greece'},
#  '25c5aeca383c212a19602a32ac4da6fe1e89b364': {'gender': 'm',
#   'age': -1,
#   'country': 'Portugal'},
#  '62b679405966787991e2cb777294435af72dba81': {'gender': 'm',
#   'age': 43,
#   'country': 'Austria'},
#  'e12d9e65da28936f4280824ea51ef035745f1472': {'gender': 'm',
#   'age': 18,
#   'country': 'United States'},
#  '07a46567cdcf9e25c9c9ecbb967d434dbb45c81d': {'gender': 'm',
#   'age': 19,
#   'country': 'United States'},
#  'fbdc7e3f517ff9ebf58e1a3f92591c0e5922fa1e': {'gender': 'm',
#   'age': 21,
#   'country': 'Peru'},
#  'ed83899f2454a1ff319c0ee1beae57b6957ffb7c': {'gender': 'm',
#   'age': 28,
#   'country': 'United Kingdom'},
#  'f7758075aac425060b1a263d2c451c0c4f58e013': {'gender': 'm',
#   'age': 18,
#   'country': 'Germany'},
#  'c5bbfb4ebc081ec8d9602eecdf0a01c25bcee651': {'gender': 'f',
#   'age': -1,
#   'country': 'Costa Rica'},
#  '7d62957d83a4fb0a5ac014bc19a550e2cfea883b': {'gender': 'm',
#   'age': 22,
#   'country': 'Poland'},
#  '23358a159d53f66a5463ea84bb01169fb75563ba': {'gender': 'f',
#   'age': -1,
#   'country': 'United States'},
#  '80cf4963a5a55e28882b55125249bcb9a8d6c013': {'gender': 'm',
#   'age': 18,
#   'country': 'United Kingdom'},
#  '2f6fcf7d577984db1aa0c68dcd4eda600ef905d9': {'gender': 'm',
#   'age': 20,
#   'country': 'United States'},
#  '704f9188c4b2d826f700d5000b0e99142822d10f': {'gender': '',
#   'age': -1,
#   'country': 'Czech Republic'},
#  'd2a7eca573d0b7a135c85298d9964b314a0d50fe': {'gender': 'm',
#   'age': 30,
#   'country': 'Spain'},
#  '92e7ef23847e1b4047a4aea545b0f03d22e51565': {'gender': 'm',
#   'age': 22,
#   'country': 'United States'},
#  '299e66864e976c755dcec1ddeeaa797591206322': {'gender': 'm',
#   'age': 25,
#   'country': 'Sweden'},
#  '8b290681b1cdb82028db7bfc7158ecf10afbd1dc': {'gender': 'm',
#   'age': 24,
#   'country': 'United Kingdom'},
#  '1478fb31d200b565519982cc309e9ec440916cf5': {'gender': 'm',
#   'age': 18,
#   'country': 'Russian Federation'},
#  'a958dc385e50c7d3b8c1063b581eafcfdede8ac9': {'gender': 'm',
#   'age': -1,
#   'country': 'Switzerland'},
#  '21bf10eacee727ad224cb0ea817bc15dbdad938e': {'gender': 'm',
#   'age': -1,
#   'country': 'Czech Republic'},
#  '39091869280573484cebeb0b2fc6a4e7ffe197bb': {'gender': '',
#   'age': -1,
#   'country': 'United Kingdom'},
#  '5a6c4bdfa560dc5b3a730eb66d84a88e3cdb0e5d': {'gender': 'f',
#   'age': 16,
#   'country': 'Poland'},
#  '204a1991e7904a177639e4863702ad5b7940705a': {'gender': 'm',
#   'age': 25,
#   'country': 'France'},
#  '682ee68e7db86e744348bf4c29214c2398e1769b': {'gender': 'm',
#   'age': 41,
#   'country': 'Switzerland'},
#  '2b310347e3c27140c31dfcb29cd2a7b756b50d27': {'gender': 'f',
#   'age': 25,
#   'country': 'Italy'},
#  '7c3c0d989862adca6c57208aa3264264bf0f2ce8': {'gender': 'm',
#   'age': 21,
#   'country': 'Serbia'},
#  'c94ebbd57873e1769ca84b9803252f77b825169f': {'gender': 'f',
#   'age': 28,
#   'country': 'Romania'},
#  '8371f1664b4d934da2a535d054bbcd7613ef90cc': {'gender': 'f',
#   'age': 20,
#   'country': 'Australia'},
#  '7ff2a67f63252f52972a6f635937b9b66c290b3c': {'gender': 'f',
#   'age': 31,
#   'country': 'Sweden'},
#  'd9c32674ea5f0b82b6ad1f48787089f5b835d478': {'gender': '',
#   'age': -1,
#   'country': 'Germany'},
#  '6a7cd304b7d730e1982e503864c1e839240a77bc': {'gender': 'm',
#   'age': 21,
#   'country': 'Brazil'},
#  'b25194e5c853c828d20a498304a53ec314e557ee': {'gender': 'm',
#   'age': 28,
#   'country': 'Micronesia, Federated States of'},
#  '2da3b8278e29c60f93b89597af6676f1d935b5cf': {'gender': 'm',
#   'age': 38,
#   'country': 'Austria'},
#  '85a5c285e04df15a63b27d1322d74a7c3ac131a7': {'gender': 'm',
#   'age': 28,
#   'country': 'Spain'},
#  'da22d0a6b90902c43937fb4af088d903fa5cf6dd': {'gender': 'f',
#   'age': 33,
#   'country': 'Brazil'},
#  '9a6a1a444f3ad66386463a44bd75d77c641d03e6': {'gender': 'm',
#   'age': 33,
#   'country': 'Germany'},
#  '039b271108b18dc4c7b90dadb53ad4e7e411ee41': {'gender': 'm',
#   'age': 16,
#   'country': 'Czech Republic'},
#  '698977c44393210346d5e6caf5262080592dc5e7': {'gender': 'm',
#   'age': -1,
#   'country': 'Australia'},
#  '1dacbc2afb75f58ae7b3ee3fe8988bc0f2a48701': {'gender': 'm',
#   'age': 31,
#   'country': 'Spain'},
#  'f107b1e47c768e4c507c5d91fa565786f67d7239': {'gender': 'm',
#   'age': -1,
#   'country': 'Spain'},
#  'b51d95799ca5fd362a66ead4dcc3b644cddc1973': {'gender': 'f',
#   'age': 27,
#   'country': 'Finland'},
#  ...}

# %%
ages = []
for user in profile:
    if profile[user]['age'] >= 0:
        ages.append(profile[user]['age'])
maxAge, minAge = max(ages), min(ages)

# %%
items = [{} for _ in range(int(maxAge // 10 + 1))]
items
# Out:
# [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}]

# %%
# 3. AgeMostPopular算法
def AgeMostPopular(train, profile, N):
    '''
    :params: train, 训练数据
    :params: profile, 用户的注册信息
    :params: N, 推荐TopN物品的个数
    :return: GetRecommendation, 获取推荐结果的接口
    '''
    
    # 对年龄进行分段
    ages = []
    for user in profile:
        if profile[user]['age'] >= 0:
            ages.append(profile[user]['age'])
    maxAge, minAge = max(ages), min(ages)
    # 划分各分段
    items = [{} for _ in range(int(maxAge // 10 + 1))]
    
    # 分年龄段进行统计
    # 对每个年龄段的item进行统计
    for user in train:
        if profile[user]['age'] >= 0:
            age = profile[user]['age'] // 10
            for item in train[user]:
                if item not in items[age]:
                    items[age][item] = 0
                items[age][item] += 1
    for i in range(len(items)):
        items[i] = list(sorted(items[i].items(), key=lambda x: x[1], reverse=True))
    
    mostPopular = MostPopular(train, profile, N)
    
    # 获取接口函数
    def GetRecommendation(user):
        seen_items = set(train[user]) if user in train else set()
        if profile[user]['age'] >= 0:
            age = profile[user]['age'] // 10
            # 年龄信息异常的，按照全局推荐
            if age >= len(items) or len(items[age]) == 0:
                recs = mostPopular(user)
            else:
                recs = [x for x in items[age] if x[0] not in seen_items][:N]
        else: # 没有提供年龄信息的，按照全局推荐
            recs = mostPopular(user)
        return recs
    
    return GetRecommendation

# %%
# 4. CountryMostPopular算法
def CountryMostPopular(train, profile, N):
    '''
    :params: train, 训练数据
    :params: profile, 用户的注册信息
    :params: N, 推荐TopN物品的个数
    :return: GetRecommendation, 获取推荐结果的接口
    '''
        
    # 分城市进行统计
    # 对每个国家的item进行统计
    items = {}
    for user in train:
        country = profile[user]['country']
        if country not in items:
            items[country] = {}
        for item in train[user]:
            if item not in items[country]:
                items[country][item] = 0
            items[country][item] += 1
    for country in items:
        items[country] = list(sorted(items[country].items(), key=lambda x: x[1], reverse=True))
    
    mostPopular = MostPopular(train, profile, N)
    
    # 获取接口函数
    def GetRecommendation(user):
        seen_items = set(train[user]) if user in train else set()
        country = profile[user]['country']
        if country in items:
            recs = [x for x in items[country] if x[0] not in seen_items][:N]
        else: # 没有提供城市信息的，按照全局推荐
            recs = mostPopular(user)
        return recs
    
    return GetRecommendation

# %%
# 5. DemographicMostPopular算法
def DemographicMostPopular(train, profile, N):
    '''
    :params: train, 训练数据
    :params: profile, 用户的注册信息
    :params: N, 推荐TopN物品的个数
    :return: GetRecommendation, 获取推荐结果的接口
    '''

    # 建立多重字典，将缺失值当成other，同归为一类进行处理
    # 对gender, age, country依次排序统计item
    items = {}
    for user in train:
        gender = profile[user]['gender']
        if gender not in items:
            items[gender] = {}
        age = profile[user]['age'] // 10
        if age not in items[gender]:
            items[gender][age] = {}
        country = profile[user]['country']
        if country not in items[gender][age]:
            items[gender][age][country] = {}
        for item in train[user]:
            if item not in items[gender][age][country]:
                items[gender][age][country][item] = 0
            items[gender][age][country][item] += 1
    for gender in items:
        for age in items[gender]:
            for country in items[gender][age]:
                items[gender][age][country] = list(sorted(items[gender][age][country].items(), 
                                                          key=lambda x: x[1], reverse=True))
                
    mostPopular = MostPopular(train, profile, N)
    
    # 获取接口函数
    def GetRecommendation(user):
        seen_items = set(train[user]) if user in train else set()
        gender = profile[user]['gender']
        age = profile[user]['age']
        country = profile[user]['country']
        if gender not in items or age not in items[gender] or country not in items[gender][age]:
            recs = mostPopular(user)
        else:
            recs = [x for x in items[gender][age][country] if x[0] not in seen_items][:N]
        return recs
    
    return GetRecommendation

# %% [markdown]
# ## 三. 实验
#
# 采用Last.FM数据集，为加快实验速度，只取5000名用户的记录进行实验
#
# 1. MostPopular实验
# 2. GenderMostPopular实验
# 3. AgeMostPopular实验
# 4. CountryMostPopular实验
# 5. DemographicMostPopular实验
#
# M=10, N=10

# %%
class Experiment():
    
    def __init__(self, M, N, at='MostPopular',
                 fp='../dataset/lastfm-dataset-360K.tar.gz_files/lastfm-dataset-360K/usersha1-artmbid-artname-plays.tsv',
                 up='../dataset/lastfm-dataset-360K.tar.gz_files/lastfm-dataset-360K/usersha1-profile.tsv'):
        '''
        :params: M, 进行多少次实验
        :params: N, TopN推荐物品的个数
        :params: fp, 数据文件路径
        :params: up, 用户注册信息文件路径
        '''
        self.M = M
        self.N = N
        self.fp = fp
        self.up = up
        self.at = at
        self.alg = {'MostPopular': MostPopular, 'GenderMostPopular': GenderMostPopular,
                    'AgeMostPopular': AgeMostPopular, 'CountryMostPopular': CountryMostPopular,
                    'DemographicMostPopular': DemographicMostPopular}
    
    # 定义单次实验
    @timmer
    def worker(self, train, test, profile):
        '''
        :params: train, 训练数据集
        :params: test, 测试数据集
        :params: profile, 用户注册信息
        :return: 各指标的值
        '''
        getRecommendation = self.alg[self.at](train, profile, self.N)
        metric = Metric(train, test, getRecommendation)
        return metric.eval()
    
    # 多次实验取平均
    @timmer
    def run(self):
        metrics = {'Precision': 0, 'Recall': 0, 
                   'Coverage': 0}
        dataset = Dataset(self.fp, self.up)
        for ii in range(self.M):
            train, test, profile = dataset.splitData(self.M, ii)
            print('Experiment {}:'.format(ii))
            metric = self.worker(train, test, profile)
            metrics = {k: metrics[k]+metric[k] for k in metrics}
        metrics = {k: metrics[k] / self.M for k in metrics}
        print('Average Result (M={}, N={}): {}'.format(\
                              self.M, self.N, metrics))

# %%
# 1. MostPopular实验
M, N = 10, 10
exp = Experiment(M, N, at='MostPopular')
exp.run()

# %%
# 2. GenderMostPopular实验
M, N = 10, 10
exp = Experiment(M, N, at='GenderMostPopular')
exp.run()

# %%
# 3. AgeMostPopular实验
M, N = 10, 10
exp = Experiment(M, N, at='AgeMostPopular')
exp.run()

# %%
# 4. CountryMostPopular实验
M, N = 10, 10
exp = Experiment(M, N, at='CountryMostPopular')
exp.run()

# %%
# 5. DemographicMostPopular实验
M, N = 10, 10
exp = Experiment(M, N, at='DemographicMostPopular')
exp.run()

# %% [markdown]
# ## 四. 实验结果
#
# 1. MostPopular实验
#
#     Running time: 340.1061339378357
#
#     Average Result (M=10, N=10): {'Precision': 2.28, 'Recall': 4.635, 'Coverage': 0.071}
#
# 2. GenderMostPopular实验
#
#     Running time: 265.6223392486572
#
#     Average Result (M=10, N=10): {'Precision': 2.326, 'Recall': 4.727, 'Coverage': 0.107}
#
# 3. AgeMostPopular实验
#
#     Running time: 205.56471586227417
#
#     Average Result (M=10, N=10): {'Precision': 2.379, 'Recall': 4.822, 'Coverage': 0.455}
#
# 4. CountryMostPopular实验
#
#     Running time: 69.32589602470398
#
#     Average Result (M=10, N=10): {'Precision': 2.415, 'Recall': 4.855, 'Coverage': 2.5}
#
# 5. DemographicMostPopular实验
#
#     Running time: 73.98487401008606
#
#     Average Result (M=10, N=10): {'Precision': 2.42, 'Recall': 4.86, 'Coverage': 2.5}

# %% [markdown]
# ## 附录：运行日志(请双击查看)
#
# 1. MostPopular实验
# Func loadData, run time: 31.807884693145752
# Func splitData, run time: 0.6068239212036133
# Experiment 0:
# Metric: {'Precision': 2.27, 'Recall': 4.61, 'Coverage': 0.08}
# Func worker, run time: 28.971026182174683
# Func splitData, run time: 0.44267868995666504
# Experiment 1:
# Metric: {'Precision': 2.26, 'Recall': 4.59, 'Coverage': 0.07}
# Func worker, run time: 28.366169691085815
# Func splitData, run time: 0.5044941902160645
# Experiment 2:
# Metric: {'Precision': 2.22, 'Recall': 4.5, 'Coverage': 0.07}
# Func worker, run time: 38.45435905456543
# Func splitData, run time: 0.4402909278869629
# Experiment 3:
# Metric: {'Precision': 2.31, 'Recall': 4.67, 'Coverage': 0.07}
# Func worker, run time: 28.688590049743652
# Func splitData, run time: 0.48880600929260254
# Experiment 4:
# Metric: {'Precision': 2.33, 'Recall': 4.77, 'Coverage': 0.07}
# Func worker, run time: 28.041622161865234
# Func splitData, run time: 0.5104248523712158
# Experiment 5:
# Metric: {'Precision': 2.2, 'Recall': 4.51, 'Coverage': 0.07}
# Func worker, run time: 28.33553171157837
# Func splitData, run time: 0.5063672065734863
# Experiment 6:
# Metric: {'Precision': 2.33, 'Recall': 4.72, 'Coverage': 0.07}
# Func worker, run time: 29.89447808265686
# Func splitData, run time: 0.4293487071990967
# Experiment 7:
# Metric: {'Precision': 2.24, 'Recall': 4.54, 'Coverage': 0.07}
# Func worker, run time: 29.959038019180298
# Func splitData, run time: 0.5041751861572266
# Experiment 8:
# Metric: {'Precision': 2.34, 'Recall': 4.71, 'Coverage': 0.07}
# Func worker, run time: 30.90305995941162
# Func splitData, run time: 0.4769570827484131
# Experiment 9:
# Metric: {'Precision': 2.3, 'Recall': 4.73, 'Coverage': 0.07}
# Func worker, run time: 31.461721897125244
# Average Result (M=10, N=10): {'Precision': 2.2800000000000002, 'Recall': 4.635, 'Coverage': 0.07100000000000002}
# Func run, run time: 340.1061339378357
#
# 2. GenderMostPopular实验
# Func loadData, run time: 32.967588901519775
# Func splitData, run time: 0.45601916313171387
# Experiment 0:
# Metric: {'Precision': 2.32, 'Recall': 4.72, 'Coverage': 0.11}
# Func worker, run time: 19.60267210006714
# Func splitData, run time: 0.5031688213348389
# Experiment 1:
# Metric: {'Precision': 2.33, 'Recall': 4.73, 'Coverage': 0.1}
# Func worker, run time: 25.32190990447998
# Func splitData, run time: 0.42341017723083496
# Experiment 2:
# Metric: {'Precision': 2.38, 'Recall': 4.82, 'Coverage': 0.1}
# Func worker, run time: 21.993903875350952
# Func splitData, run time: 0.505748987197876
# Experiment 3:
# Metric: {'Precision': 2.4, 'Recall': 4.86, 'Coverage': 0.1}
# Func worker, run time: 25.69679093360901
# Func splitData, run time: 0.5266520977020264
# Experiment 4:
# Metric: {'Precision': 2.22, 'Recall': 4.54, 'Coverage': 0.11}
# Func worker, run time: 21.68884301185608
# Func splitData, run time: 0.5205812454223633
# Experiment 5:
# Metric: {'Precision': 2.31, 'Recall': 4.74, 'Coverage': 0.11}
# Func worker, run time: 24.315038204193115
# Func splitData, run time: 0.6323270797729492
# Experiment 6:
# Metric: {'Precision': 2.33, 'Recall': 4.7, 'Coverage': 0.11}
# Func worker, run time: 24.59072780609131
# Func splitData, run time: 0.5137548446655273
# Experiment 7:
# Metric: {'Precision': 2.35, 'Recall': 4.76, 'Coverage': 0.11}
# Func worker, run time: 21.767657995224
# Func splitData, run time: 0.5112850666046143
# Experiment 8:
# Metric: {'Precision': 2.3, 'Recall': 4.64, 'Coverage': 0.11}
# Func worker, run time: 21.0389301776886
# Func splitData, run time: 0.5135531425476074
# Experiment 9:
# Metric: {'Precision': 2.32, 'Recall': 4.76, 'Coverage': 0.11}
# Func worker, run time: 21.189006090164185
# Average Result (M=10, N=10): {'Precision': 2.326, 'Recall': 4.726999999999999, 'Coverage': 0.10700000000000001}
# Func run, run time: 265.6223392486572
#
# 3. AgeMostPopular实验
# Func loadData, run time: 30.702067852020264
# Func splitData, run time: 3.189789295196533
# Experiment 0:
# Metric: {'Precision': 2.34, 'Recall': 4.75, 'Coverage': 0.45}
# Func worker, run time: 14.813374996185303
# Func splitData, run time: 0.5000729560852051
# Experiment 1:
# Metric: {'Precision': 2.36, 'Recall': 4.78, 'Coverage': 0.46}
# Func worker, run time: 18.69653296470642
# Func splitData, run time: 0.714263916015625
# Experiment 2:
# Metric: {'Precision': 2.5, 'Recall': 5.06, 'Coverage': 0.46}
# Func worker, run time: 16.40371298789978
# Func splitData, run time: 0.42107224464416504
# Experiment 3:
# Metric: {'Precision': 2.41, 'Recall': 4.86, 'Coverage': 0.47}
# Func worker, run time: 16.157140016555786
# Func splitData, run time: 0.44391894340515137
# Experiment 4:
# Metric: {'Precision': 2.32, 'Recall': 4.73, 'Coverage': 0.45}
# Func worker, run time: 16.057992935180664
# Func splitData, run time: 0.4891808032989502
# Experiment 5:
# Metric: {'Precision': 2.33, 'Recall': 4.75, 'Coverage': 0.45}
# Func worker, run time: 16.826287746429443
# Func splitData, run time: 0.5030360221862793
# Experiment 6:
# Metric: {'Precision': 2.38, 'Recall': 4.8, 'Coverage': 0.46}
# Func worker, run time: 15.631379127502441
# Func splitData, run time: 0.508782148361206
# Experiment 7:
# Metric: {'Precision': 2.32, 'Recall': 4.7, 'Coverage': 0.45}
# Func worker, run time: 15.04989218711853
# Func splitData, run time: 0.4729750156402588
# Experiment 8:
# Metric: {'Precision': 2.5, 'Recall': 5.02, 'Coverage': 0.46}
# Func worker, run time: 19.40653085708618
# Func splitData, run time: 0.4343280792236328
# Experiment 9:
# Metric: {'Precision': 2.33, 'Recall': 4.77, 'Coverage': 0.44}
# Func worker, run time: 17.756699085235596
# Average Result (M=10, N=10): {'Precision': 2.379, 'Recall': 4.822, 'Coverage': 0.45500000000000007}
# Func run, run time: 205.56471586227417
#
# 4. CountryMostPopular实验
# Func loadData, run time: 30.24172306060791
# Func splitData, run time: 0.4623088836669922
# Experiment 0:
# Metric: {'Precision': 2.41, 'Recall': 4.85, 'Coverage': 2.53}
# Func worker, run time: 3.4046268463134766
# Func splitData, run time: 0.43274497985839844
# Experiment 1:
# Metric: {'Precision': 2.39, 'Recall': 4.79, 'Coverage': 2.49}
# Func worker, run time: 3.3446362018585205
# Func splitData, run time: 0.5451531410217285
# Experiment 2:
# Metric: {'Precision': 2.35, 'Recall': 4.72, 'Coverage': 2.52}
# Func worker, run time: 3.223905086517334
# Func splitData, run time: 0.4849269390106201
# Experiment 3:
# Metric: {'Precision': 2.39, 'Recall': 4.76, 'Coverage': 2.5}
# Func worker, run time: 3.1288833618164062
# Func splitData, run time: 0.44620418548583984
# Experiment 4:
# Metric: {'Precision': 2.4, 'Recall': 4.86, 'Coverage': 2.48}
# Func worker, run time: 3.3267481327056885
# Func splitData, run time: 0.4455292224884033
# Experiment 5:
# Metric: {'Precision': 2.4, 'Recall': 4.86, 'Coverage': 2.53}
# Func worker, run time: 3.6315438747406006
# Func splitData, run time: 0.5009069442749023
# Experiment 6:
# Metric: {'Precision': 2.38, 'Recall': 4.76, 'Coverage': 2.5}
# Func worker, run time: 4.013977766036987
# Func splitData, run time: 0.5759139060974121
# Experiment 7:
# Metric: {'Precision': 2.47, 'Recall': 4.96, 'Coverage': 2.48}
# Func worker, run time: 3.3212859630584717
# Func splitData, run time: 0.4942488670349121
# Experiment 8:
# Metric: {'Precision': 2.53, 'Recall': 5.05, 'Coverage': 2.48}
# Func worker, run time: 3.3335418701171875
# Func splitData, run time: 0.43490123748779297
# Experiment 9:
# Metric: {'Precision': 2.43, 'Recall': 4.94, 'Coverage': 2.49}
# Func worker, run time: 3.2024052143096924
# Average Result (M=10, N=10): {'Precision': 2.415, 'Recall': 4.854999999999999, 'Coverage': 2.5}
# Func run, run time: 69.32589602470398
#
# 5. DemographicMostPopular实验
# Func loadData, run time: 31.048221826553345
# Func splitData, run time: 0.6405370235443115
# Experiment 0:
# Metric: {'Precision': 2.41, 'Recall': 4.85, 'Coverage': 2.53}
# Func worker, run time: 3.8784639835357666
# Func splitData, run time: 0.5229880809783936
# Experiment 1:
# Metric: {'Precision': 2.39, 'Recall': 4.79, 'Coverage': 2.49}
# Func worker, run time: 3.4125118255615234
# Func splitData, run time: 0.43076014518737793
# Experiment 2:
# Metric: {'Precision': 2.35, 'Recall': 4.72, 'Coverage': 2.52}
# Func worker, run time: 3.470226287841797
# Func splitData, run time: 0.4595067501068115
# Experiment 3:
# Metric: {'Precision': 2.39, 'Recall': 4.76, 'Coverage': 2.5}
# Func worker, run time: 3.9592530727386475
# Func splitData, run time: 0.5331680774688721
# Experiment 4:
# Metric: {'Precision': 2.4, 'Recall': 4.86, 'Coverage': 2.48}
# Func worker, run time: 4.06541109085083
# Func splitData, run time: 0.5062789916992188
# Experiment 5:
# Metric: {'Precision': 2.4, 'Recall': 4.86, 'Coverage': 2.53}
# Func worker, run time: 3.6064438819885254
# Func splitData, run time: 0.4431419372558594
# Experiment 6:
# Metric: {'Precision': 2.38, 'Recall': 4.76, 'Coverage': 2.5}
# Func worker, run time: 3.7960410118103027
# Func splitData, run time: 0.5151360034942627
# Experiment 7:
# Metric: {'Precision': 2.47, 'Recall': 4.96, 'Coverage': 2.48}
# Func worker, run time: 4.031769037246704
# Func splitData, run time: 0.4504380226135254
# Experiment 8:
# Metric: {'Precision': 2.53, 'Recall': 5.05, 'Coverage': 2.48}
# Func worker, run time: 3.66860294342041
# Func splitData, run time: 0.5212371349334717
# Experiment 9:
# Metric: {'Precision': 2.43, 'Recall': 4.94, 'Coverage': 2.49}
# Func worker, run time: 3.6845691204071045
# Average Result (M=10, N=10): {'Precision': 2.415, 'Recall': 4.854999999999999, 'Coverage': 2.5}
# Func run, run time: 73.98487401008606
